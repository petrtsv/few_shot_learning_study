# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tabulate import tabulate

# %matplotlib inline

# %%
INDEX_FILE = r'D:\petrtsv\projects\ds\few_shot_learning_study\index.csv'

records = pd.read_csv(INDEX_FILE, index_col=0)
records = records[
    (records['version'].isin({
        '1.0.6', '1.0.7', '1.0.8', '1.0.9', '1.0.10', '1.0.12'
    }))
]

records = records[records['is_test'] == True]
records = records[records['distance'] != 'sen']

records.columns
# Out:
# Index(['Name', 'Explanation', 'n_iterations', 'n_way', 'n_shot', 'batch_size',
#        'eval_period', 'eval_iterations', 'time', 'accuracy', 'iteration',
#        'result_directory', 'image_size', 'backbone', 'aux_location_k',
#        'aux_rotation_k', 'dataset', 'train_classes', 'test_n_iterations',
#        'dfmn_k', 'distance', 'k', 'test_batch_size', 'test_dataset',
#        'test_n_way', 'test_accuracy', 'testing_time', 'accuracy_std',
#        'top_3_accuracy', 'top_3_accuracy_std', 'test_accuracy_std',
#        'test_top_3_accuracy', 'test_top_3_accuracy_std', 'version', 'is_test',
#        'test_balanced', 'is_feat', 'is_relevance'],
#       dtype='object')

# %%
COLUMNS = ['dataset', 'test_dataset', 'n_shot', 'k', 'aux_rotation_k', 'dfmn_k', 'is_feat',
           'distance', 'test_accuracy', 'test_accuracy_std', 'test_top_3_accuracy', 'test_top_3_accuracy_std']
records = records[COLUMNS].sort_values(by='test_accuracy', ascending=False)
# records.head()

# %% [markdown]
# # Raw resuts tables

# %% [markdown]
# * ## MiniImageNet -> MiniImageNet (5-way)

# %%
records_miniImageNet_miniImageNet = records[(records['dataset'] == 'miniImageNet') & (
    records['test_dataset'] == 'miniImageNet-test')]
records_miniImageNet_miniImageNet
# Out:
#           dataset       test_dataset  n_shot    k  aux_rotation_k  dfmn_k  \
# 335  miniImageNet  miniImageNet-test     5.0  0.2             0.0     1.0
# 326  miniImageNet  miniImageNet-test     5.0  1.0             1.0     0.0
# 320  miniImageNet  miniImageNet-test     5.0  1.0             1.0     0.0
# 329  miniImageNet  miniImageNet-test     5.0  0.2             0.0     1.0
# 341  miniImageNet  miniImageNet-test     5.0  0.2             0.0     1.0
# 293  miniImageNet  miniImageNet-test     5.0  1.0             0.0     0.0
# 314  miniImageNet  miniImageNet-test     5.0  1.0             1.0     0.0
# 344  miniImageNet  miniImageNet-test     5.0  0.2             0.0     1.0
# 332  miniImageNet  miniImageNet-test     5.0  0.2             0.0     1.0
# 347  miniImageNet  miniImageNet-test     5.0  0.2             1.0     1.0
# 311  miniImageNet  miniImageNet-test     5.0  1.0             1.0     0.0
# 323  miniImageNet  miniImageNet-test     5.0  1.0             1.0     0.0
# 299  miniImageNet  miniImageNet-test     5.0  1.0             0.0     0.0
# 338  miniImageNet  miniImageNet-test     5.0  0.2             0.0     1.0
# 356  miniImageNet  miniImageNet-test     5.0  0.2             1.0     1.0
# 362  miniImageNet  miniImageNet-test     5.0  0.2             1.0     1.0
# 353  miniImageNet  miniImageNet-test     5.0  0.2             1.0     1.0
# 296  miniImageNet  miniImageNet-test     5.0  1.0             0.0     0.0
# 359  miniImageNet  miniImageNet-test     5.0  0.2             1.0     1.0
# 317  miniImageNet  miniImageNet-test     5.0  1.0             1.0     0.0
# 302  miniImageNet  miniImageNet-test     5.0  1.0             0.0     0.0
# 290  miniImageNet  miniImageNet-test     5.0  1.0             0.0     0.0
# 305  miniImageNet  miniImageNet-test     5.0  1.0             0.0     0.0
# 350  miniImageNet  miniImageNet-test     5.0  0.2             1.0     1.0
# 256  miniImageNet  miniImageNet-test     1.0  1.0             1.0     0.0
# 262  miniImageNet  miniImageNet-test     1.0  1.0             1.0     0.0
# 244  miniImageNet  miniImageNet-test     1.0  1.0             0.0     0.0
# 268  miniImageNet  miniImageNet-test     1.0  0.2             0.0     1.0
# 274  miniImageNet  miniImageNet-test     1.0  0.2             0.0     1.0
# 259  miniImageNet  miniImageNet-test     1.0  1.0             1.0     0.0
# 250  miniImageNet  miniImageNet-test     1.0  1.0             0.0     0.0
# 247  miniImageNet  miniImageNet-test     1.0  1.0             0.0     0.0
# 238  miniImageNet  miniImageNet-test     1.0  0.2             1.0     1.0
# 102  miniImageNet  miniImageNet-test     1.0  0.2             0.0     1.0
# 234  miniImageNet  miniImageNet-test     1.0  0.2             1.0     1.0
# 271  miniImageNet  miniImageNet-test     1.0  0.2             0.0     1.0
# 287  miniImageNet  miniImageNet-test     1.0  0.2             1.0     1.0
# 105  miniImageNet  miniImageNet-test     1.0  0.2             0.0     1.0
# 96   miniImageNet  miniImageNet-test     1.0  1.0             1.0     0.0
# 111  miniImageNet  miniImageNet-test     1.0  0.2             1.0     1.0
# 90   miniImageNet  miniImageNet-test     1.0  1.0             0.0     0.0
# 265  miniImageNet  miniImageNet-test     1.0  0.2             0.0     1.0
# 231  miniImageNet  miniImageNet-test     1.0  0.2             1.0     1.0
# 253  miniImageNet  miniImageNet-test     1.0  1.0             1.0     0.0
# 108  miniImageNet  miniImageNet-test     1.0  0.2             1.0     1.0
# 99   miniImageNet  miniImageNet-test     1.0  1.0             1.0     0.0
# 241  miniImageNet  miniImageNet-test     1.0  1.0             0.0     0.0
# 93   miniImageNet  miniImageNet-test     1.0  1.0             0.0     0.0
#
#     is_feat      distance  test_accuracy  test_accuracy_std  \
# 335   False  cosine_scale        0.70256           0.011138
# 326    True     euclidean        0.69976           0.011174
# 320    True  cosine_scale        0.69976           0.011256
# 329   False          sen2        0.69712           0.010923
# 341   False     euclidean        0.69568           0.010963
# 293    True     euclidean        0.69360           0.010922
# 314    True          sen2        0.69288           0.011282
# 344    True     euclidean        0.69152           0.011254
# 332    True          sen2        0.69016           0.011032
# 347   False  cosine_scale        0.68988           0.010975
# 311   False          sen2        0.68756           0.011053
# 323   False     euclidean        0.68616           0.011031
# 299    True          sen2        0.68548           0.011310
# 338    True  cosine_scale        0.68456           0.011302
# 356    True          sen2        0.68428           0.011121
# 362    True     euclidean        0.68324           0.011342
# 353   False          sen2        0.68012           0.011291
# 296   False          sen2        0.67932           0.011154
# 359   False     euclidean        0.67792           0.011323
# 317   False  cosine_scale        0.67768           0.011090
# 302   False  cosine_scale        0.67728           0.011057
# 290   False     euclidean        0.67652           0.011026
# 305    True  cosine_scale        0.66924           0.011517
# 350    True  cosine_scale        0.65396           0.011018
# 256    True          sen2        0.55036           0.012554
# 262    True     euclidean        0.54856           0.012015
# 244    True          sen2        0.54836           0.012398
# 268    True          sen2        0.54780           0.012280
# 274    True     euclidean        0.54736           0.012530
# 259    True  cosine_scale        0.54608           0.012614
# 250    True     euclidean        0.54596           0.012560
# 247    True  cosine_scale        0.54404           0.012460
# 238    True     euclidean        0.54364           0.011941
# 102     NaN  cosine_scale        0.54172           0.012168
# 234    True          sen2        0.52960           0.011880
# 271    True  cosine_scale        0.52920           0.012394
# 287    True  cosine_scale        0.52920           0.012190
# 105     NaN     euclidean        0.52612           0.012111
# 96      NaN  cosine_scale        0.52608           0.011888
# 111     NaN  cosine_scale        0.52496           0.012409
# 90      NaN  cosine_scale        0.51988           0.012215
# 265   False          sen2        0.51932           0.011904
# 231   False          sen2        0.51008           0.011880
# 253   False          sen2        0.50976           0.012128
# 108     NaN     euclidean        0.50896           0.011912
# 99      NaN     euclidean        0.50884           0.012070
# 241   False          sen2        0.50784           0.012153
# 93      NaN     euclidean        0.50084           0.012488
#
#      test_top_3_accuracy  test_top_3_accuracy_std
# 335              0.95456                 0.004466
# 326              0.95392                 0.004583
# 320              0.95316                 0.004696
# 329              0.94964                 0.004748
# 341              0.95080                 0.004878
# 293              0.95036                 0.004768
# 314              0.95068                 0.004688
# 344              0.95236                 0.004872
# 332              0.95052                 0.004957
# 347              0.94972                 0.004998
# 311              0.94700                 0.005084
# 323              0.94696                 0.005042
# 299              0.94932                 0.004947
# 338              0.94876                 0.005105
# 356              0.94932                 0.005096
# 362              0.94840                 0.004941
# 353              0.94740                 0.005186
# 296              0.94628                 0.005059
# 359              0.94652                 0.005146
# 317              0.94500                 0.005077
# 302              0.94740                 0.004874
# 290              0.94484                 0.005213
# 305              0.94300                 0.005080
# 350              0.93172                 0.005827
# 256              0.89400                 0.007725
# 262              0.88948                 0.007888
# 244              0.89476                 0.007772
# 268              0.89360                 0.007824
# 274              0.88864                 0.008059
# 259              0.89152                 0.007921
# 250              0.89288                 0.007827
# 247              0.89084                 0.007973
# 238              0.88740                 0.007864
# 102              0.88832                 0.008049
# 234              0.88320                 0.008066
# 271              0.88064                 0.008243
# 287              0.87272                 0.008396
# 105              0.88124                 0.008050
# 96               0.87768                 0.007975
# 111              0.87680                 0.008227
# 90               0.87504                 0.008113
# 265              0.87568                 0.008242
# 231              0.87084                 0.008205
# 253              0.87732                 0.008099
# 108              0.86884                 0.008482
# 99               0.87048                 0.008438
# 241              0.87168                 0.008273
# 93               0.87060                 0.008452

# %% [markdown]
# * ## GoogleLandmarks -> GoogleLandmarks (100-way)

# %%
records_googleLandmarks_googleLandmarks = records[(
    records['dataset'] == 'google-landmarks') & (records['test_dataset'] == 'google-landmarks-test')]
records_googleLandmarks_googleLandmarks
# Out:
#               dataset           test_dataset  n_shot    k  aux_rotation_k  \
# 176  google-landmarks  google-landmarks-test     5.0  1.0             0.0
# 154  google-landmarks  google-landmarks-test     5.0  0.2             0.0
# 185  google-landmarks  google-landmarks-test     5.0  1.0             1.0
# 221  google-landmarks  google-landmarks-test     5.0  1.0             1.0
# 212  google-landmarks  google-landmarks-test     5.0  1.0             0.0
# 215  google-landmarks  google-landmarks-test     5.0  1.0             0.0
# 145  google-landmarks  google-landmarks-test     5.0  1.0             1.0
# 218  google-landmarks  google-landmarks-test     5.0  1.0             1.0
# 136  google-landmarks  google-landmarks-test     5.0  1.0             0.0
# 182  google-landmarks  google-landmarks-test     5.0  1.0             1.0
# 224  google-landmarks  google-landmarks-test     5.0  0.2             0.0
# 200  google-landmarks  google-landmarks-test     5.0  0.2             1.0
# 163  google-landmarks  google-landmarks-test     5.0  0.2             1.0
# 173  google-landmarks  google-landmarks-test     5.0  1.0             0.0
# 142  google-landmarks  google-landmarks-test     5.0  1.0             1.0
# 133  google-landmarks  google-landmarks-test     5.0  1.0             0.0
# 209  google-landmarks  google-landmarks-test     5.0  0.2             1.0
# 151  google-landmarks  google-landmarks-test     5.0  0.2             0.0
# 227  google-landmarks  google-landmarks-test     5.0  0.2             0.0
# 191  google-landmarks  google-landmarks-test     5.0  0.2             0.0
# 194  google-landmarks  google-landmarks-test     5.0  0.2             0.0
# 160  google-landmarks  google-landmarks-test     5.0  0.2             1.0
# 203  google-landmarks  google-landmarks-test     5.0  0.2             1.0
# 206  google-landmarks  google-landmarks-test     5.0  0.2             1.0
#
#      dfmn_k is_feat      distance  test_accuracy  test_accuracy_std  \
# 176     0.0    True     euclidean       0.403063           0.002916
# 154     1.0     NaN     euclidean       0.398087           0.003023
# 185     0.0    True     euclidean       0.397973           0.003024
# 221     0.0    True          sen2       0.397013           0.002938
# 212     0.0   False          sen2       0.394947           0.002881
# 215     0.0    True          sen2       0.394810           0.003048
# 145     0.0     NaN     euclidean       0.391510           0.003040
# 218     0.0   False          sen2       0.389960           0.002931
# 136     0.0     NaN     euclidean       0.389737           0.002974
# 182     0.0    True  cosine_scale       0.388960           0.002961
# 224     1.0   False          sen2       0.388860           0.002988
# 200     1.0   False          sen2       0.386233           0.002967
# 163     1.0     NaN     euclidean       0.385843           0.002915
# 173     0.0    True  cosine_scale       0.385330           0.002956
# 142     0.0     NaN  cosine_scale       0.382373           0.002881
# 133     0.0     NaN  cosine_scale       0.375750           0.002962
# 209     1.0    True     euclidean       0.375747           0.002951
# 151     1.0     NaN  cosine_scale       0.375173           0.002951
# 227     1.0    True          sen2       0.371747           0.002879
# 191     1.0    True  cosine_scale       0.371570           0.002956
# 194     1.0    True     euclidean       0.371563           0.002908
# 160     1.0     NaN  cosine_scale       0.369180           0.002924
# 203     1.0    True          sen2       0.365283           0.002928
# 206     1.0    True  cosine_scale       0.361760           0.002853
#
#      test_top_3_accuracy  test_top_3_accuracy_std
# 176             0.564527                 0.003058
# 154             0.555110                 0.003080
# 185             0.558590                 0.002981
# 221             0.557697                 0.002992
# 212             0.555990                 0.003006
# 215             0.557850                 0.003112
# 145             0.550580                 0.003067
# 218             0.549320                 0.003029
# 136             0.549083                 0.003053
# 182             0.546497                 0.003040
# 224             0.548670                 0.003148
# 200             0.544100                 0.003080
# 163             0.540213                 0.002998
# 173             0.544340                 0.003062
# 142             0.539007                 0.003079
# 133             0.532150                 0.003102
# 209             0.536657                 0.003046
# 151             0.537263                 0.002986
# 227             0.534457                 0.003042
# 191             0.533410                 0.002971
# 194             0.532813                 0.003045
# 160             0.529673                 0.003090
# 203             0.526343                 0.003041
# 206             0.522857                 0.002969

# %% [markdown]
# * ## miniImageNet -> GoogleLandmarks (100-way)

# %%
records_miniImageNet_googleLandmarks = records[(records['dataset'] == 'miniImageNet') & (
    records['test_dataset'] == 'google-landmarks-test')]
records_miniImageNet_googleLandmarks
# Out:
#           dataset           test_dataset  n_shot    k  aux_rotation_k  dfmn_k  \
# 334  miniImageNet  google-landmarks-test     5.0  0.2             0.0     1.0
# 346  miniImageNet  google-landmarks-test     5.0  0.2             1.0     1.0
# 340  miniImageNet  google-landmarks-test     5.0  0.2             0.0     1.0
# 358  miniImageNet  google-landmarks-test     5.0  0.2             1.0     1.0
# 352  miniImageNet  google-landmarks-test     5.0  0.2             1.0     1.0
# 328  miniImageNet  google-landmarks-test     5.0  0.2             0.0     1.0
# 361  miniImageNet  google-landmarks-test     5.0  0.2             1.0     1.0
# 355  miniImageNet  google-landmarks-test     5.0  0.2             1.0     1.0
# 343  miniImageNet  google-landmarks-test     5.0  0.2             0.0     1.0
# 331  miniImageNet  google-landmarks-test     5.0  0.2             0.0     1.0
# 337  miniImageNet  google-landmarks-test     5.0  0.2             0.0     1.0
# 349  miniImageNet  google-landmarks-test     5.0  0.2             1.0     1.0
# 310  miniImageNet  google-landmarks-test     5.0  1.0             1.0     0.0
# 319  miniImageNet  google-landmarks-test     5.0  1.0             1.0     0.0
# 322  miniImageNet  google-landmarks-test     5.0  1.0             1.0     0.0
# 316  miniImageNet  google-landmarks-test     5.0  1.0             1.0     0.0
# 313  miniImageNet  google-landmarks-test     5.0  1.0             1.0     0.0
# 325  miniImageNet  google-landmarks-test     5.0  1.0             1.0     0.0
# 289  miniImageNet  google-landmarks-test     5.0  1.0             0.0     0.0
# 295  miniImageNet  google-landmarks-test     5.0  1.0             0.0     0.0
# 292  miniImageNet  google-landmarks-test     5.0  1.0             0.0     0.0
# 298  miniImageNet  google-landmarks-test     5.0  1.0             0.0     0.0
# 301  miniImageNet  google-landmarks-test     5.0  1.0             0.0     0.0
# 304  miniImageNet  google-landmarks-test     5.0  1.0             0.0     0.0
# 273  miniImageNet  google-landmarks-test     1.0  0.2             0.0     1.0
# 267  miniImageNet  google-landmarks-test     1.0  0.2             0.0     1.0
# 237  miniImageNet  google-landmarks-test     1.0  0.2             1.0     1.0
# 110  miniImageNet  google-landmarks-test     1.0  0.2             1.0     1.0
# 264  miniImageNet  google-landmarks-test     1.0  0.2             0.0     1.0
# 101  miniImageNet  google-landmarks-test     1.0  0.2             0.0     1.0
# 104  miniImageNet  google-landmarks-test     1.0  0.2             0.0     1.0
# 230  miniImageNet  google-landmarks-test     1.0  0.2             1.0     1.0
# 107  miniImageNet  google-landmarks-test     1.0  0.2             1.0     1.0
# 286  miniImageNet  google-landmarks-test     1.0  0.2             1.0     1.0
# 233  miniImageNet  google-landmarks-test     1.0  0.2             1.0     1.0
# 270  miniImageNet  google-landmarks-test     1.0  0.2             0.0     1.0
# 258  miniImageNet  google-landmarks-test     1.0  1.0             1.0     0.0
# 255  miniImageNet  google-landmarks-test     1.0  1.0             1.0     0.0
# 261  miniImageNet  google-landmarks-test     1.0  1.0             1.0     0.0
# 246  miniImageNet  google-landmarks-test     1.0  1.0             0.0     0.0
# 249  miniImageNet  google-landmarks-test     1.0  1.0             0.0     0.0
# 252  miniImageNet  google-landmarks-test     1.0  1.0             1.0     0.0
# 243  miniImageNet  google-landmarks-test     1.0  1.0             0.0     0.0
# 98   miniImageNet  google-landmarks-test     1.0  1.0             1.0     0.0
# 240  miniImageNet  google-landmarks-test     1.0  1.0             0.0     0.0
# 92   miniImageNet  google-landmarks-test     1.0  1.0             0.0     0.0
# 95   miniImageNet  google-landmarks-test     1.0  1.0             1.0     0.0
# 89   miniImageNet  google-landmarks-test     1.0  1.0             0.0     0.0
#
#     is_feat      distance  test_accuracy  test_accuracy_std  \
# 334   False  cosine_scale       0.298163           0.002841
# 346   False  cosine_scale       0.296500           0.002854
# 340   False     euclidean       0.294780           0.002826
# 358   False     euclidean       0.291260           0.002807
# 352   False          sen2       0.291140           0.002800
# 328   False          sen2       0.288387           0.002810
# 361    True     euclidean       0.285417           0.002732
# 355    True          sen2       0.285097           0.002810
# 343    True     euclidean       0.284860           0.002772
# 331    True          sen2       0.283223           0.002822
# 337    True  cosine_scale       0.275087           0.002741
# 349    True  cosine_scale       0.266340           0.002686
# 310   False          sen2       0.261250           0.002659
# 319    True  cosine_scale       0.258763           0.002639
# 322   False     euclidean       0.258383           0.002687
# 316   False  cosine_scale       0.254160           0.002577
# 313    True          sen2       0.253153           0.002628
# 325    True     euclidean       0.250990           0.002673
# 289   False     euclidean       0.249997           0.002684
# 295   False          sen2       0.245817           0.002612
# 292    True     euclidean       0.235443           0.002554
# 298    True          sen2       0.233360           0.002536
# 301   False  cosine_scale       0.221313           0.002453
# 304    True  cosine_scale       0.214747           0.002494
# 273    True     euclidean       0.156113           0.002147
# 267    True          sen2       0.155183           0.002166
# 237    True     euclidean       0.154597           0.002112
# 110     NaN  cosine_scale       0.154273           0.002133
# 264   False          sen2       0.154240           0.002201
# 101     NaN  cosine_scale       0.153877           0.002113
# 104     NaN     euclidean       0.153243           0.002177
# 230   False          sen2       0.151030           0.002149
# 107     NaN     euclidean       0.150200           0.002174
# 286    True  cosine_scale       0.149357           0.002109
# 233    True          sen2       0.145107           0.002081
# 270    True  cosine_scale       0.144107           0.002012
# 258    True  cosine_scale       0.136230           0.002002
# 255    True          sen2       0.135513           0.001993
# 261    True     euclidean       0.134820           0.001929
# 246    True  cosine_scale       0.128217           0.001958
# 249    True     euclidean       0.125520           0.001901
# 252   False          sen2       0.125420           0.001918
# 243    True          sen2       0.123597           0.001985
# 98      NaN     euclidean       0.123120           0.001908
# 240   False          sen2       0.120070           0.001881
# 92      NaN     euclidean       0.117967           0.001830
# 95      NaN  cosine_scale       0.114643           0.001866
# 89      NaN  cosine_scale       0.097750           0.001751
#
#      test_top_3_accuracy  test_top_3_accuracy_std
# 334             0.442427                 0.003031
# 346             0.440613                 0.003068
# 340             0.436453                 0.003082
# 358             0.433643                 0.003011
# 352             0.433180                 0.003020
# 328             0.432220                 0.003006
# 361             0.427733                 0.002954
# 355             0.428590                 0.002962
# 343             0.427430                 0.002988
# 331             0.426860                 0.002925
# 337             0.414583                 0.002966
# 349             0.406187                 0.002930
# 310             0.399037                 0.003012
# 319             0.397353                 0.002913
# 322             0.394590                 0.003003
# 316             0.389623                 0.002949
# 313             0.391107                 0.002885
# 325             0.388020                 0.002986
# 289             0.387680                 0.003113
# 295             0.382100                 0.002965
# 292             0.370703                 0.002899
# 298             0.367360                 0.002880
# 301             0.351367                 0.002927
# 304             0.347397                 0.002866
# 273             0.249660                 0.002685
# 267             0.249073                 0.002661
# 237             0.247660                 0.002615
# 110             0.247513                 0.002632
# 264             0.247287                 0.002670
# 101             0.246670                 0.002618
# 104             0.246063                 0.002658
# 230             0.243780                 0.002603
# 107             0.242930                 0.002624
# 286             0.241840                 0.002496
# 233             0.236777                 0.002627
# 270             0.237230                 0.002574
# 258             0.227277                 0.002462
# 255             0.225323                 0.002491
# 261             0.224567                 0.002474
# 246             0.216647                 0.002509
# 249             0.213317                 0.002390
# 252             0.212870                 0.002381
# 243             0.211247                 0.002452
# 98              0.207670                 0.002461
# 240             0.205767                 0.002421
# 92              0.200723                 0.002332
# 95              0.197450                 0.002352
# 89              0.175857                 0.002223

# %% [markdown]
# # Обработанные результаты
#
# ### Основа - https://arxiv.org/pdf/1703.05175.pdf - для каждого экземпляра класса получаем вектор признаков, затем усредняем по классам
#
# Реализованы следующие "модули":
#
# * Функции потерь
#     1. DFMN - https://arxiv.org/abs/2002.12017v1 - глобальные прототипы для всех классов из тренировочного набора
#     2. Rotation task - https://openaccess.thecvf.com/content_ICCV_2019/papers/Gidaris_Boosting_Few-Shot_Visual_Learning_With_Self-Supervision_ICCV_2019_paper.pdf - параллельно с основной задачей учимся распозновать, на какой угол повернули картинку (0, 90, 180 или 270 градусов)
# * Преобразования прототипов
#     1. FEAT - https://openaccess.thecvf.com/content_CVPR_2020/html/Ye_Few-Shot_Learning_via_Embedding_Adaptation_With_Set-to-Set_Functions_CVPR_2020_paper.html - архитектура "трансформер" - преобразовываем прототип с опорой на остальные прототипы.
# * Функции расстояния
#     1. Euclidean - обычное евклидово расстояние
#     2. Scaled euclidean - https://arxiv.org/abs/2002.12017v1 - евклидово расстояние между нормированными векторами, допольнительно умноженными на число, определяемое для вектора отедльной нейросетью
#     3. SEN - https://www.ecva.net/papers/eccv_2020/papers_ECCV/html/4238_ECCV_2020_paper.php - корень из суммы евклидового расстояния между векторами и евклидового расстояния между длинами векторов, умноженным на коэффициент. Во время обучения коэффициент разный для правильных и неправильных пар (1.0 и -(10^-7) соотвественно), во время теста он равен 1.0
#
# ### Датасеты - miniImageNet - мало разных классов и подмножество googleLandmarks - много похожих классов
#
# Сценарии (1-shot для googleLandmarks не проверялось, тк точность будет слишком маленькая):
#
# * Обучаем на miniImageNet (15-way classification), тестируем на miniImageNet (5-way classification) - стандартный датасет в статьях
#     * 1-shot
#     * 5-shot
#
# * Обучаем на miniImageNet (15-way classification), тестируем на googleLandmarks (100-way classification) - адаптируемся к новому датасету, в котором меньше разнообразие и больше классов
#     * 5-shot
#
# * Обучаем на googleLandmarks (15-way classification), тестируем на miniImageNet (5-way classification) - адаптируемся к новому датасету, в котором больше разнообразие и меньше классов
#     * 5-shot
#
# * Обучаем на googleLandmarks (15-way classification), тестируем на googleLandmarks (100-way classification)
#     * 5-shot

# %%
DISTANCES = {
    'cosine_scale': 'Scaled euclidean',
    'euclidean': 'Euclidean',
    'sen2': 'SEN',
}

def bool_repr(value):
    return '+' if value else '-'

def row2params(row):
    return bool_repr(row['aux_rotation_k'] == 1.0), bool_repr(row['dfmn_k'] == 1.0), bool_repr(row['is_feat'] == True), DISTANCES[row['distance']]


def accuracy_repr(row):
    return "%.3f $+-$ %.3f" % (row['test_accuracy'], row['test_accuracy_std'])


def top3_accuracy_repr(row):
    return "%.3f $+-$ %.3f" % (row['test_top_3_accuracy'], row['test_top_3_accuracy_std'])

# %%
def tabulate_bold(*args, **kwargs):
    res = tabulate(*args, **kwargs).split('\n')
    ln = res[4]
    its = ln.split()
    for i in range(len(its)):
        if not (len(its[i]) == 0 or its[i][-1] == '&' or its[i][-1] == '\\' or its[i][-1] == '$'):
            its[i] = '\\textbf{' + its[i] + '}'
    res[4] = ' '.join(its)
    return '\n'.join(res)

# %%
configurations = {}

for i, row in records.iterrows():
    ds_from = row['dataset']
    ds_to = row['test_dataset']
    n_shot = str(int(row['n_shot']))

    case = ds_from + '2' + ds_to + '_' + n_shot + 'shot'

    cur = row2params(row)

    if cur not in configurations:
        configurations[cur] = {}

    configurations[cur][case] = {
        'accuracy': row['test_accuracy'],
        'accuracy_std': row['test_accuracy_std'],
        'top3_accuracy': row['test_top_3_accuracy'],
        'top3_accuracy_std': row['test_top_3_accuracy_std'],
        'row': row
    }

configurations
# Out:
# {('-',
#   '+',
#   '-',
#   'Scaled euclidean'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.7025599999999999,
#    'accuracy_std': 0.01113773166612783,
#    'top3_accuracy': 0.954559862613678,
#    'top3_accuracy_std': 0.00446569122090389,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                False
#    distance                        cosine_scale
#    test_accuracy                        0.70256
#    test_accuracy_std                  0.0111377
#    test_top_3_accuracy                  0.95456
#    test_top_3_accuracy_std           0.00446569
#    Name: 335, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.5417200000000002,
#    'accuracy_std': 0.01216828013490162,
#    'top3_accuracy': 0.8883197903633118,
#    'top3_accuracy_std': 0.00804916060165083,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                  NaN
#    distance                        cosine_scale
#    test_accuracy                        0.54172
#    test_accuracy_std                  0.0121683
#    test_top_3_accuracy                  0.88832
#    test_top_3_accuracy_std           0.00804916
#    Name: 102, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.5410400000000001,
#    'accuracy_std': 0.011621244293057385,
#    'top3_accuracy': 0.8880798816680908,
#    'top3_accuracy_std': 0.0072407213058909205,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                  NaN
#    distance                        cosine_scale
#    test_accuracy                        0.54104
#    test_accuracy_std                  0.0116212
#    test_top_3_accuracy                  0.88808
#    test_top_3_accuracy_std           0.00724072
#    Name: 152, dtype: object}, 'google-landmarks2google-landmarks-test_5shot': {'accuracy': 0.37517333333333336,
#    'accuracy_std': 0.0029509045117450733,
#    'top3_accuracy': 0.5372633934020996,
#    'top3_accuracy_std': 0.002985935805197704,
#    'row': dataset                         google-landmarks
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                      NaN
#    distance                            cosine_scale
#    test_accuracy                           0.375173
#    test_accuracy_std                      0.0029509
#    test_top_3_accuracy                     0.537263
#    test_top_3_accuracy_std               0.00298594
#    Name: 151, dtype: object}, 'miniImageNet2google-landmarks-test_5shot': {'accuracy': 0.2981633333333333,
#    'accuracy_std': 0.0028413400206791697,
#    'top3_accuracy': 0.4424267113208771,
#    'top3_accuracy_std': 0.003031103634632034,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                    False
#    distance                            cosine_scale
#    test_accuracy                           0.298163
#    test_accuracy_std                     0.00284134
#    test_top_3_accuracy                     0.442427
#    test_top_3_accuracy_std                0.0030311
#    Name: 334, dtype: object}, 'miniImageNet2google-landmarks-test_1shot': {'accuracy': 0.1538766666666667,
#    'accuracy_std': 0.0021130328932621955,
#    'top3_accuracy': 0.2466699928045273,
#    'top3_accuracy_std': 0.002618273278405357,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                      NaN
#    distance                            cosine_scale
#    test_accuracy                           0.153877
#    test_accuracy_std                     0.00211303
#    test_top_3_accuracy                      0.24667
#    test_top_3_accuracy_std               0.00261827
#    Name: 101, dtype: object}},
#  ('+',
#   '-',
#   '+',
#   'Euclidean'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.6997599999999999,
#    'accuracy_std': 0.011173949111157565,
#    'top3_accuracy': 0.9539198875427246,
#    'top3_accuracy_std': 0.004582608768516364,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                          1
#    aux_rotation_k                             1
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                           euclidean
#    test_accuracy                        0.69976
#    test_accuracy_std                  0.0111739
#    test_top_3_accuracy                  0.95392
#    test_top_3_accuracy_std           0.00458261
#    Name: 326, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.56248,
#    'accuracy_std': 0.011325268566709934,
#    'top3_accuracy': 0.8966398835182191,
#    'top3_accuracy_std': 0.0068370413182398,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                          1
#    aux_rotation_k                             1
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                           euclidean
#    test_accuracy                        0.56248
#    test_accuracy_std                  0.0113253
#    test_top_3_accuracy                  0.89664
#    test_top_3_accuracy_std           0.00683704
#    Name: 186, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.54856,
#    'accuracy_std': 0.012014528142481776,
#    'top3_accuracy': 0.8894798755645752,
#    'top3_accuracy_std': 0.007888256327737467,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                          1
#    aux_rotation_k                             1
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                           euclidean
#    test_accuracy                        0.54856
#    test_accuracy_std                  0.0120145
#    test_top_3_accuracy                  0.88948
#    test_top_3_accuracy_std           0.00788826
#    Name: 262, dtype: object}, 'google-landmarks2google-landmarks-test_5shot': {'accuracy': 0.39797333333333335,
#    'accuracy_std': 0.0030241658650244684,
#    'top3_accuracy': 0.5585900545120239,
#    'top3_accuracy_std': 0.0029809215947676397,
#    'row': dataset                         google-landmarks
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                              1
#    aux_rotation_k                                 1
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                               euclidean
#    test_accuracy                           0.397973
#    test_accuracy_std                     0.00302417
#    test_top_3_accuracy                      0.55859
#    test_top_3_accuracy_std               0.00298092
#    Name: 185, dtype: object}, 'miniImageNet2google-landmarks-test_5shot': {'accuracy': 0.25099,
#    'accuracy_std': 0.00267320502863606,
#    'top3_accuracy': 0.3880199790000916,
#    'top3_accuracy_std': 0.0029863415222525186,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                              1
#    aux_rotation_k                                 1
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                               euclidean
#    test_accuracy                            0.25099
#    test_accuracy_std                     0.00267321
#    test_top_3_accuracy                      0.38802
#    test_top_3_accuracy_std               0.00298634
#    Name: 325, dtype: object}, 'miniImageNet2google-landmarks-test_1shot': {'accuracy': 0.13482,
#    'accuracy_std': 0.0019292045589387962,
#    'top3_accuracy': 0.2245666682720185,
#    'top3_accuracy_std': 0.002473586200792359,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                              1
#    aux_rotation_k                                 1
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                               euclidean
#    test_accuracy                            0.13482
#    test_accuracy_std                      0.0019292
#    test_top_3_accuracy                     0.224567
#    test_top_3_accuracy_std               0.00247359
#    Name: 261, dtype: object}},
#  ('+',
#   '-',
#   '+',
#   'Scaled euclidean'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.6997599999999997,
#    'accuracy_std': 0.011256206456163802,
#    'top3_accuracy': 0.9531598687171936,
#    'top3_accuracy_std': 0.0046958045336338424,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                          1
#    aux_rotation_k                             1
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                        cosine_scale
#    test_accuracy                        0.69976
#    test_accuracy_std                  0.0112562
#    test_top_3_accuracy                  0.95316
#    test_top_3_accuracy_std            0.0046958
#    Name: 320, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.5548000000000001,
#    'accuracy_std': 0.011203024044772357,
#    'top3_accuracy': 0.8924798965454102,
#    'top3_accuracy_std': 0.007052601475394647,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                          1
#    aux_rotation_k                             1
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                        cosine_scale
#    test_accuracy                         0.5548
#    test_accuracy_std                   0.011203
#    test_top_3_accuracy                  0.89248
#    test_top_3_accuracy_std            0.0070526
#    Name: 183, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.5460799999999998,
#    'accuracy_std': 0.012614246771869564,
#    'top3_accuracy': 0.8915199041366577,
#    'top3_accuracy_std': 0.007921284806025598,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                          1
#    aux_rotation_k                             1
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                        cosine_scale
#    test_accuracy                        0.54608
#    test_accuracy_std                  0.0126142
#    test_top_3_accuracy                  0.89152
#    test_top_3_accuracy_std           0.00792128
#    Name: 259, dtype: object}, 'google-landmarks2google-landmarks-test_5shot': {'accuracy': 0.38896,
#    'accuracy_std': 0.002961289387215445,
#    'top3_accuracy': 0.5464966297149658,
#    'top3_accuracy_std': 0.003039914550915648,
#    'row': dataset                         google-landmarks
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                              1
#    aux_rotation_k                                 1
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                            cosine_scale
#    test_accuracy                            0.38896
#    test_accuracy_std                     0.00296129
#    test_top_3_accuracy                     0.546497
#    test_top_3_accuracy_std               0.00303991
#    Name: 182, dtype: object}, 'miniImageNet2google-landmarks-test_5shot': {'accuracy': 0.2587633333333333,
#    'accuracy_std': 0.002639451193449614,
#    'top3_accuracy': 0.397353321313858,
#    'top3_accuracy_std': 0.0029130124055395602,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                              1
#    aux_rotation_k                                 1
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                            cosine_scale
#    test_accuracy                           0.258763
#    test_accuracy_std                     0.00263945
#    test_top_3_accuracy                     0.397353
#    test_top_3_accuracy_std               0.00291301
#    Name: 319, dtype: object}, 'miniImageNet2google-landmarks-test_1shot': {'accuracy': 0.13623,
#    'accuracy_std': 0.002001696952760505,
#    'top3_accuracy': 0.22727665305137634,
#    'top3_accuracy_std': 0.0024620342205042643,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                              1
#    aux_rotation_k                                 1
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                            cosine_scale
#    test_accuracy                            0.13623
#    test_accuracy_std                      0.0020017
#    test_top_3_accuracy                     0.227277
#    test_top_3_accuracy_std               0.00246203
#    Name: 258, dtype: object}},
#  ('-',
#   '+',
#   '-',
#   'SEN'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.6971200000000001,
#    'accuracy_std': 0.010922703688000326,
#    'top3_accuracy': 0.949639856815338,
#    'top3_accuracy_std': 0.004747944476358578,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                False
#    distance                                sen2
#    test_accuracy                        0.69712
#    test_accuracy_std                  0.0109227
#    test_top_3_accuracy                  0.94964
#    test_top_3_accuracy_std           0.00474794
#    Name: 329, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.5552000000000001,
#    'accuracy_std': 0.0113997629183503,
#    'top3_accuracy': 0.891759991645813,
#    'top3_accuracy_std': 0.007084116643204803,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                False
#    distance                                sen2
#    test_accuracy                         0.5552
#    test_accuracy_std                  0.0113998
#    test_top_3_accuracy                  0.89176
#    test_top_3_accuracy_std           0.00708412
#    Name: 225, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.51932,
#    'accuracy_std': 0.01190394650283435,
#    'top3_accuracy': 0.8756798505783081,
#    'top3_accuracy_std': 0.008241696669357002,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                False
#    distance                                sen2
#    test_accuracy                        0.51932
#    test_accuracy_std                  0.0119039
#    test_top_3_accuracy                  0.87568
#    test_top_3_accuracy_std            0.0082417
#    Name: 265, dtype: object}, 'google-landmarks2google-landmarks-test_5shot': {'accuracy': 0.38886,
#    'accuracy_std': 0.002988115197316266,
#    'top3_accuracy': 0.5486700534820557,
#    'top3_accuracy_std': 0.003148029664134155,
#    'row': dataset                         google-landmarks
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                    False
#    distance                                    sen2
#    test_accuracy                            0.38886
#    test_accuracy_std                     0.00298812
#    test_top_3_accuracy                      0.54867
#    test_top_3_accuracy_std               0.00314803
#    Name: 224, dtype: object}, 'miniImageNet2google-landmarks-test_5shot': {'accuracy': 0.2883866666666666,
#    'accuracy_std': 0.002809567238573954,
#    'top3_accuracy': 0.4322200417518616,
#    'top3_accuracy_std': 0.003006406845862421,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                    False
#    distance                                    sen2
#    test_accuracy                           0.288387
#    test_accuracy_std                     0.00280957
#    test_top_3_accuracy                      0.43222
#    test_top_3_accuracy_std               0.00300641
#    Name: 328, dtype: object}, 'miniImageNet2google-landmarks-test_1shot': {'accuracy': 0.15424000000000002,
#    'accuracy_std': 0.002200919272859786,
#    'top3_accuracy': 0.2472866773605347,
#    'top3_accuracy_std': 0.002669656742597141,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                    False
#    distance                                    sen2
#    test_accuracy                            0.15424
#    test_accuracy_std                     0.00220092
#    test_top_3_accuracy                     0.247287
#    test_top_3_accuracy_std               0.00266966
#    Name: 264, dtype: object}},
#  ('-',
#   '+',
#   '-',
#   'Euclidean'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.6956800000000001,
#    'accuracy_std': 0.010963221726784078,
#    'top3_accuracy': 0.9507998824119568,
#    'top3_accuracy_std': 0.004878487472865941,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                False
#    distance                           euclidean
#    test_accuracy                        0.69568
#    test_accuracy_std                  0.0109632
#    test_top_3_accuracy                   0.9508
#    test_top_3_accuracy_std           0.00487849
#    Name: 341, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.5574400000000002,
#    'accuracy_std': 0.011695785950888849,
#    'top3_accuracy': 0.8914398550987244,
#    'top3_accuracy_std': 0.00676206070693002,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                  NaN
#    distance                           euclidean
#    test_accuracy                        0.55744
#    test_accuracy_std                  0.0116958
#    test_top_3_accuracy                  0.89144
#    test_top_3_accuracy_std           0.00676206
#    Name: 155, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.52612,
#    'accuracy_std': 0.012110953124572223,
#    'top3_accuracy': 0.8812399506568909,
#    'top3_accuracy_std': 0.008050326861477386,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                  NaN
#    distance                           euclidean
#    test_accuracy                        0.52612
#    test_accuracy_std                   0.012111
#    test_top_3_accuracy                  0.88124
#    test_top_3_accuracy_std           0.00805033
#    Name: 105, dtype: object}, 'google-landmarks2google-landmarks-test_5shot': {'accuracy': 0.3980866666666667,
#    'accuracy_std': 0.0030229109134062154,
#    'top3_accuracy': 0.555109977722168,
#    'top3_accuracy_std': 0.003079963913359661,
#    'row': dataset                         google-landmarks
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                      NaN
#    distance                               euclidean
#    test_accuracy                           0.398087
#    test_accuracy_std                     0.00302291
#    test_top_3_accuracy                      0.55511
#    test_top_3_accuracy_std               0.00307996
#    Name: 154, dtype: object}, 'miniImageNet2google-landmarks-test_5shot': {'accuracy': 0.29478000000000004,
#    'accuracy_std': 0.002825871538118807,
#    'top3_accuracy': 0.43645328283309937,
#    'top3_accuracy_std': 0.0030819292378734464,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                    False
#    distance                               euclidean
#    test_accuracy                            0.29478
#    test_accuracy_std                     0.00282587
#    test_top_3_accuracy                     0.436453
#    test_top_3_accuracy_std               0.00308193
#    Name: 340, dtype: object}, 'miniImageNet2google-landmarks-test_1shot': {'accuracy': 0.15324333333333331,
#    'accuracy_std': 0.0021769166419654353,
#    'top3_accuracy': 0.2460633069276809,
#    'top3_accuracy_std': 0.0026578351089006627,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                      NaN
#    distance                               euclidean
#    test_accuracy                           0.153243
#    test_accuracy_std                     0.00217692
#    test_top_3_accuracy                     0.246063
#    test_top_3_accuracy_std               0.00265784
#    Name: 104, dtype: object}},
#  ('-',
#   '-',
#   '+',
#   'Euclidean'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.6936000000000001,
#    'accuracy_std': 0.010922429192238296,
#    'top3_accuracy': 0.9503600001335144,
#    'top3_accuracy_std': 0.004767636950236051,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                          1
#    aux_rotation_k                             0
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                           euclidean
#    test_accuracy                         0.6936
#    test_accuracy_std                  0.0109224
#    test_top_3_accuracy                  0.95036
#    test_top_3_accuracy_std           0.00476764
#    Name: 293, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.5624400000000002,
#    'accuracy_std': 0.011446249789089615,
#    'top3_accuracy': 0.8958798050880432,
#    'top3_accuracy_std': 0.006831185280262202,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                          1
#    aux_rotation_k                             0
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                           euclidean
#    test_accuracy                        0.56244
#    test_accuracy_std                  0.0114462
#    test_top_3_accuracy                  0.89588
#    test_top_3_accuracy_std           0.00683119
#    Name: 177, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.54596,
#    'accuracy_std': 0.012559795143793302,
#    'top3_accuracy': 0.892879843711853,
#    'top3_accuracy_std': 0.007827248215973994,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                          1
#    aux_rotation_k                             0
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                           euclidean
#    test_accuracy                        0.54596
#    test_accuracy_std                  0.0125598
#    test_top_3_accuracy                  0.89288
#    test_top_3_accuracy_std           0.00782725
#    Name: 250, dtype: object}, 'google-landmarks2google-landmarks-test_5shot': {'accuracy': 0.4030633333333333,
#    'accuracy_std': 0.002916427514862911,
#    'top3_accuracy': 0.5645267367362976,
#    'top3_accuracy_std': 0.003057864349882586,
#    'row': dataset                         google-landmarks
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                              1
#    aux_rotation_k                                 0
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                               euclidean
#    test_accuracy                           0.403063
#    test_accuracy_std                     0.00291643
#    test_top_3_accuracy                     0.564527
#    test_top_3_accuracy_std               0.00305786
#    Name: 176, dtype: object}, 'miniImageNet2google-landmarks-test_5shot': {'accuracy': 0.2354433333333333,
#    'accuracy_std': 0.0025537330817163827,
#    'top3_accuracy': 0.3707033097743988,
#    'top3_accuracy_std': 0.002899043263407905,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                              1
#    aux_rotation_k                                 0
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                               euclidean
#    test_accuracy                           0.235443
#    test_accuracy_std                     0.00255373
#    test_top_3_accuracy                     0.370703
#    test_top_3_accuracy_std               0.00289904
#    Name: 292, dtype: object}, 'miniImageNet2google-landmarks-test_1shot': {'accuracy': 0.12552,
#    'accuracy_std': 0.0019010998344591425,
#    'top3_accuracy': 0.2133166342973709,
#    'top3_accuracy_std': 0.0023900648567254518,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                              1
#    aux_rotation_k                                 0
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                               euclidean
#    test_accuracy                            0.12552
#    test_accuracy_std                      0.0019011
#    test_top_3_accuracy                     0.213317
#    test_top_3_accuracy_std               0.00239006
#    Name: 249, dtype: object}},
#  ('+',
#   '-',
#   '+',
#   'SEN'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.6928799999999999,
#    'accuracy_std': 0.011282013749071321,
#    'top3_accuracy': 0.9506799578666688,
#    'top3_accuracy_std': 0.004688050319435503,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                          1
#    aux_rotation_k                             1
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                                sen2
#    test_accuracy                        0.69288
#    test_accuracy_std                   0.011282
#    test_top_3_accuracy                  0.95068
#    test_top_3_accuracy_std           0.00468805
#    Name: 314, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.5564000000000001,
#    'accuracy_std': 0.011344181347741688,
#    'top3_accuracy': 0.8914398550987244,
#    'top3_accuracy_std': 0.006953336507199375,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                          1
#    aux_rotation_k                             1
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                                sen2
#    test_accuracy                         0.5564
#    test_accuracy_std                  0.0113442
#    test_top_3_accuracy                  0.89144
#    test_top_3_accuracy_std           0.00695334
#    Name: 222, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.5503600000000002,
#    'accuracy_std': 0.012553550303608359,
#    'top3_accuracy': 0.8939999938011169,
#    'top3_accuracy_std': 0.007724536773285206,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                          1
#    aux_rotation_k                             1
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                                sen2
#    test_accuracy                        0.55036
#    test_accuracy_std                  0.0125536
#    test_top_3_accuracy                    0.894
#    test_top_3_accuracy_std           0.00772454
#    Name: 256, dtype: object}, 'google-landmarks2google-landmarks-test_5shot': {'accuracy': 0.3970133333333333,
#    'accuracy_std': 0.002937609223152043,
#    'top3_accuracy': 0.5576966404914856,
#    'top3_accuracy_std': 0.002991772405511525,
#    'row': dataset                         google-landmarks
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                              1
#    aux_rotation_k                                 1
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                                    sen2
#    test_accuracy                           0.397013
#    test_accuracy_std                     0.00293761
#    test_top_3_accuracy                     0.557697
#    test_top_3_accuracy_std               0.00299177
#    Name: 221, dtype: object}, 'miniImageNet2google-landmarks-test_5shot': {'accuracy': 0.2531533333333333,
#    'accuracy_std': 0.002628234391376845,
#    'top3_accuracy': 0.3911066353321075,
#    'top3_accuracy_std': 0.002884943712222918,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                              1
#    aux_rotation_k                                 1
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                                    sen2
#    test_accuracy                           0.253153
#    test_accuracy_std                     0.00262823
#    test_top_3_accuracy                     0.391107
#    test_top_3_accuracy_std               0.00288494
#    Name: 313, dtype: object}, 'miniImageNet2google-landmarks-test_1shot': {'accuracy': 0.13551333333333332,
#    'accuracy_std': 0.0019932389223074605,
#    'top3_accuracy': 0.2253233045339585,
#    'top3_accuracy_std': 0.0024911573187277342,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                              1
#    aux_rotation_k                                 1
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                                    sen2
#    test_accuracy                           0.135513
#    test_accuracy_std                     0.00199324
#    test_top_3_accuracy                     0.225323
#    test_top_3_accuracy_std               0.00249116
#    Name: 255, dtype: object}},
#  ('-',
#   '+',
#   '+',
#   'Euclidean'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.6915199999999999,
#    'accuracy_std': 0.011254344346369837,
#    'top3_accuracy': 0.9523599147796632,
#    'top3_accuracy_std': 0.0048717150373943224,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                 True
#    distance                           euclidean
#    test_accuracy                        0.69152
#    test_accuracy_std                  0.0112543
#    test_top_3_accuracy                  0.95236
#    test_top_3_accuracy_std           0.00487172
#    Name: 344, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.5473600000000001,
#    'accuracy_std': 0.012530118813382306,
#    'top3_accuracy': 0.8886398673057556,
#    'top3_accuracy_std': 0.008058653249814876,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                 True
#    distance                           euclidean
#    test_accuracy                        0.54736
#    test_accuracy_std                  0.0125301
#    test_top_3_accuracy                  0.88864
#    test_top_3_accuracy_std           0.00805865
#    Name: 274, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.5410400000000001,
#    'accuracy_std': 0.011183851936794591,
#    'top3_accuracy': 0.8836798071861267,
#    'top3_accuracy_std': 0.007150919299245926,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                 True
#    distance                           euclidean
#    test_accuracy                        0.54104
#    test_accuracy_std                  0.0111839
#    test_top_3_accuracy                  0.88368
#    test_top_3_accuracy_std           0.00715092
#    Name: 195, dtype: object}, 'google-landmarks2google-landmarks-test_5shot': {'accuracy': 0.3715633333333334,
#    'accuracy_std': 0.002908360786158152,
#    'top3_accuracy': 0.5328134298324585,
#    'top3_accuracy_std': 0.003045396678924609,
#    'row': dataset                         google-landmarks
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                     True
#    distance                               euclidean
#    test_accuracy                           0.371563
#    test_accuracy_std                     0.00290836
#    test_top_3_accuracy                     0.532813
#    test_top_3_accuracy_std                0.0030454
#    Name: 194, dtype: object}, 'miniImageNet2google-landmarks-test_5shot': {'accuracy': 0.28485999999999995,
#    'accuracy_std': 0.002772094534482564,
#    'top3_accuracy': 0.4274300336837769,
#    'top3_accuracy_std': 0.00298820789138708,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                     True
#    distance                               euclidean
#    test_accuracy                            0.28486
#    test_accuracy_std                     0.00277209
#    test_top_3_accuracy                      0.42743
#    test_top_3_accuracy_std               0.00298821
#    Name: 343, dtype: object}, 'miniImageNet2google-landmarks-test_1shot': {'accuracy': 0.15611333333333335,
#    'accuracy_std': 0.0021474300584316736,
#    'top3_accuracy': 0.24966000020504,
#    'top3_accuracy_std': 0.0026850640951421824,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                     True
#    distance                               euclidean
#    test_accuracy                           0.156113
#    test_accuracy_std                     0.00214743
#    test_top_3_accuracy                      0.24966
#    test_top_3_accuracy_std               0.00268506
#    Name: 273, dtype: object}},
#  ('-',
#   '+',
#   '+',
#   'SEN'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.69016,
#    'accuracy_std': 0.011032129326538806,
#    'top3_accuracy': 0.9505199193954468,
#    'top3_accuracy_std': 0.004957230862470679,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                 True
#    distance                                sen2
#    test_accuracy                        0.69016
#    test_accuracy_std                  0.0110321
#    test_top_3_accuracy                  0.95052
#    test_top_3_accuracy_std           0.00495723
#    Name: 332, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.5478,
#    'accuracy_std': 0.012280197198874434,
#    'top3_accuracy': 0.893599808216095,
#    'top3_accuracy_std': 0.007823641292401309,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                 True
#    distance                                sen2
#    test_accuracy                         0.5478
#    test_accuracy_std                  0.0122802
#    test_top_3_accuracy                   0.8936
#    test_top_3_accuracy_std           0.00782364
#    Name: 268, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.5464,
#    'accuracy_std': 0.011372418031882756,
#    'top3_accuracy': 0.8847998976707458,
#    'top3_accuracy_std': 0.0072629876798643985,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             0
#    dfmn_k                                     1
#    is_feat                                 True
#    distance                                sen2
#    test_accuracy                         0.5464
#    test_accuracy_std                  0.0113724
#    test_top_3_accuracy                   0.8848
#    test_top_3_accuracy_std           0.00726299
#    Name: 228, dtype: object}, 'google-landmarks2google-landmarks-test_5shot': {'accuracy': 0.37174666666666667,
#    'accuracy_std': 0.002878650556950083,
#    'top3_accuracy': 0.534456729888916,
#    'top3_accuracy_std': 0.003042235761382567,
#    'row': dataset                         google-landmarks
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                     True
#    distance                                    sen2
#    test_accuracy                           0.371747
#    test_accuracy_std                     0.00287865
#    test_top_3_accuracy                     0.534457
#    test_top_3_accuracy_std               0.00304224
#    Name: 227, dtype: object}, 'miniImageNet2google-landmarks-test_5shot': {'accuracy': 0.2832233333333333,
#    'accuracy_std': 0.002821799718912323,
#    'top3_accuracy': 0.4268600046634674,
#    'top3_accuracy_std': 0.0029249990826720985,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                     True
#    distance                                    sen2
#    test_accuracy                           0.283223
#    test_accuracy_std                      0.0028218
#    test_top_3_accuracy                      0.42686
#    test_top_3_accuracy_std                 0.002925
#    Name: 331, dtype: object}, 'miniImageNet2google-landmarks-test_1shot': {'accuracy': 0.15518333333333334,
#    'accuracy_std': 0.0021663773195569344,
#    'top3_accuracy': 0.249073326587677,
#    'top3_accuracy_std': 0.00266051679967761,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                            0.2
#    aux_rotation_k                                 0
#    dfmn_k                                         1
#    is_feat                                     True
#    distance                                    sen2
#    test_accuracy                           0.155183
#    test_accuracy_std                     0.00216638
#    test_top_3_accuracy                     0.249073
#    test_top_3_accuracy_std               0.00266052
#    Name: 267, dtype: object}},
#  ('+',
#   '+',
#   '-',
#   'Scaled euclidean'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.68988,
#    'accuracy_std': 0.010974821962889288,
#    'top3_accuracy': 0.9497199058532716,
#    'top3_accuracy_std': 0.004997946760076174,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             1
#    dfmn_k                                     1
#    is_feat                                False
#    distance                        cosine_scale
#    test_accuracy                        0.68988
#    test_accuracy_std                  0.0109748
#    test_top_3_accuracy                  0.94972
#    test_top_3_accuracy_std           0.00499795
#    Name: 347, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.55008,
#    'accuracy_std': 0.011659119927227679,
#    'top3_accuracy': 0.8903998136520386,
#    'top3_accuracy_std': 0.007021613598390923,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             1
#    dfmn_k                                     1
#    is_feat                                  NaN
#    distance                        cosine_scale
#    test_accuracy                        0.55008
#    test_accuracy_std                  0.0116591
#    test_top_3_accuracy                   0.8904
#    test_top_3_accuracy_std           0.00702161
#    Name: 161, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.52496,
#    'accuracy_std': 0.012409019678015241,
#    'top3_accuracy': 0.8767998814582825,
#    'top3_accuracy_std': 0.008227047739111292,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                        0.2
#    aux_rotation_k                             1
#    dfmn_k                                     1
#    is_feat                                  NaN
#    distance                        cosine_scale
#    test_accuracy                        0.52496
#    test_accuracy_std                   0.012409
#    test_top_3_accuracy                   0.8768
# ...
#    'top3_accuracy': 0.17585667967796326,
#    'top3_accuracy_std': 0.002223272030924175,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                              1
#    aux_rotation_k                                 0
#    dfmn_k                                         0
#    is_feat                                      NaN
#    distance                            cosine_scale
#    test_accuracy                            0.09775
#    test_accuracy_std                     0.00175146
#    test_top_3_accuracy                     0.175857
#    test_top_3_accuracy_std               0.00222327
#    Name: 89, dtype: object}},
#  ('-',
#   '-',
#   '-',
#   'Euclidean'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.6765200000000001,
#    'accuracy_std': 0.011025559821132416,
#    'top3_accuracy': 0.9448398947715759,
#    'top3_accuracy_std': 0.005213093425110696,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                          1
#    aux_rotation_k                             0
#    dfmn_k                                     0
#    is_feat                                False
#    distance                           euclidean
#    test_accuracy                        0.67652
#    test_accuracy_std                  0.0110256
#    test_top_3_accuracy                  0.94484
#    test_top_3_accuracy_std           0.00521309
#    Name: 290, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.5608000000000002,
#    'accuracy_std': 0.011296878305950695,
#    'top3_accuracy': 0.8949998021125793,
#    'top3_accuracy_std': 0.0066069849048529024,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                          1
#    aux_rotation_k                             0
#    dfmn_k                                     0
#    is_feat                                  NaN
#    distance                           euclidean
#    test_accuracy                         0.5608
#    test_accuracy_std                  0.0112969
#    test_top_3_accuracy                    0.895
#    test_top_3_accuracy_std           0.00660698
#    Name: 137, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.5008400000000001,
#    'accuracy_std': 0.01248829881157588,
#    'top3_accuracy': 0.8705998659133911,
#    'top3_accuracy_std': 0.008451898392726916,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                          1
#    aux_rotation_k                             0
#    dfmn_k                                     0
#    is_feat                                  NaN
#    distance                           euclidean
#    test_accuracy                        0.50084
#    test_accuracy_std                  0.0124883
#    test_top_3_accuracy                   0.8706
#    test_top_3_accuracy_std            0.0084519
#    Name: 93, dtype: object}, 'google-landmarks2google-landmarks-test_5shot': {'accuracy': 0.3897366666666668,
#    'accuracy_std': 0.002973872865443279,
#    'top3_accuracy': 0.5490832924842834,
#    'top3_accuracy_std': 0.0030534014622796233,
#    'row': dataset                         google-landmarks
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                              1
#    aux_rotation_k                                 0
#    dfmn_k                                         0
#    is_feat                                      NaN
#    distance                               euclidean
#    test_accuracy                           0.389737
#    test_accuracy_std                     0.00297387
#    test_top_3_accuracy                     0.549083
#    test_top_3_accuracy_std                0.0030534
#    Name: 136, dtype: object}, 'miniImageNet2google-landmarks-test_5shot': {'accuracy': 0.2499966666666667,
#    'accuracy_std': 0.002683971610059167,
#    'top3_accuracy': 0.3876800239086151,
#    'top3_accuracy_std': 0.0031129164080530326,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                              1
#    aux_rotation_k                                 0
#    dfmn_k                                         0
#    is_feat                                    False
#    distance                               euclidean
#    test_accuracy                           0.249997
#    test_accuracy_std                     0.00268397
#    test_top_3_accuracy                      0.38768
#    test_top_3_accuracy_std               0.00311292
#    Name: 289, dtype: object}, 'miniImageNet2google-landmarks-test_1shot': {'accuracy': 0.11796666666666668,
#    'accuracy_std': 0.0018299559390156735,
#    'top3_accuracy': 0.2007233202457428,
#    'top3_accuracy_std': 0.0023321727791713012,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                              1
#    aux_rotation_k                                 0
#    dfmn_k                                         0
#    is_feat                                      NaN
#    distance                               euclidean
#    test_accuracy                           0.117967
#    test_accuracy_std                     0.00182996
#    test_top_3_accuracy                     0.200723
#    test_top_3_accuracy_std               0.00233217
#    Name: 92, dtype: object}},
#  ('-',
#   '-',
#   '+',
#   'Scaled euclidean'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.6692400000000001,
#    'accuracy_std': 0.01151740648984189,
#    'top3_accuracy': 0.9429998993873596,
#    'top3_accuracy_std': 0.0050800793714193045,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                          1
#    aux_rotation_k                             0
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                        cosine_scale
#    test_accuracy                        0.66924
#    test_accuracy_std                  0.0115174
#    test_top_3_accuracy                    0.943
#    test_top_3_accuracy_std           0.00508008
#    Name: 305, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.54484,
#    'accuracy_std': 0.011492800096323528,
#    'top3_accuracy': 0.8896398544311523,
#    'top3_accuracy_std': 0.007170428352259769,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                          1
#    aux_rotation_k                             0
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                        cosine_scale
#    test_accuracy                        0.54484
#    test_accuracy_std                  0.0114928
#    test_top_3_accuracy                  0.88964
#    test_top_3_accuracy_std           0.00717043
#    Name: 174, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.5440400000000001,
#    'accuracy_std': 0.012459548384510015,
#    'top3_accuracy': 0.8908399939537048,
#    'top3_accuracy_std': 0.00797252814233216,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                          1
#    aux_rotation_k                             0
#    dfmn_k                                     0
#    is_feat                                 True
#    distance                        cosine_scale
#    test_accuracy                        0.54404
#    test_accuracy_std                  0.0124595
#    test_top_3_accuracy                  0.89084
#    test_top_3_accuracy_std           0.00797253
#    Name: 247, dtype: object}, 'google-landmarks2google-landmarks-test_5shot': {'accuracy': 0.38533,
#    'accuracy_std': 0.0029558682408147123,
#    'top3_accuracy': 0.5443400144577026,
#    'top3_accuracy_std': 0.003062459413599226,
#    'row': dataset                         google-landmarks
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                              1
#    aux_rotation_k                                 0
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                            cosine_scale
#    test_accuracy                            0.38533
#    test_accuracy_std                     0.00295587
#    test_top_3_accuracy                      0.54434
#    test_top_3_accuracy_std               0.00306246
#    Name: 173, dtype: object}, 'miniImageNet2google-landmarks-test_5shot': {'accuracy': 0.2147466666666667,
#    'accuracy_std': 0.0024936801801435627,
#    'top3_accuracy': 0.3473966717720032,
#    'top3_accuracy_std': 0.002866063202573179,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                              1
#    aux_rotation_k                                 0
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                            cosine_scale
#    test_accuracy                           0.214747
#    test_accuracy_std                     0.00249368
#    test_top_3_accuracy                     0.347397
#    test_top_3_accuracy_std               0.00286606
#    Name: 304, dtype: object}, 'miniImageNet2google-landmarks-test_1shot': {'accuracy': 0.12821666666666665,
#    'accuracy_std': 0.0019577308829893387,
#    'top3_accuracy': 0.21664664149284368,
#    'top3_accuracy_std': 0.0025087627176337696,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                              1
#    aux_rotation_k                                 0
#    dfmn_k                                         0
#    is_feat                                     True
#    distance                            cosine_scale
#    test_accuracy                           0.128217
#    test_accuracy_std                     0.00195773
#    test_top_3_accuracy                     0.216647
#    test_top_3_accuracy_std               0.00250876
#    Name: 246, dtype: object}},
#  ('+',
#   '+',
#   '+',
#   'Scaled euclidean'): {'miniImageNet2miniImageNet-test_5shot': {'accuracy': 0.6539599999999999,
#    'accuracy_std': 0.011017561084570951,
#    'top3_accuracy': 0.9317199587821959,
#    'top3_accuracy_std': 0.005826501563959734,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             1
#    dfmn_k                                     1
#    is_feat                                 True
#    distance                        cosine_scale
#    test_accuracy                        0.65396
#    test_accuracy_std                  0.0110176
#    test_top_3_accuracy                  0.93172
#    test_top_3_accuracy_std            0.0058265
#    Name: 350, dtype: object}, 'google-landmarks2miniImageNet-test_5shot': {'accuracy': 0.5414,
#    'accuracy_std': 0.011502463504252762,
#    'top3_accuracy': 0.8849599361419678,
#    'top3_accuracy_std': 0.00711159301789438,
#    'row': dataset                     google-landmarks
#    test_dataset               miniImageNet-test
#    n_shot                                     5
#    k                                        0.2
#    aux_rotation_k                             1
#    dfmn_k                                     1
#    is_feat                                 True
#    distance                        cosine_scale
#    test_accuracy                         0.5414
#    test_accuracy_std                  0.0115025
#    test_top_3_accuracy                  0.88496
#    test_top_3_accuracy_std           0.00711159
#    Name: 207, dtype: object}, 'miniImageNet2miniImageNet-test_1shot': {'accuracy': 0.5291999999999998,
#    'accuracy_std': 0.012190145185338836,
#    'top3_accuracy': 0.8727198839187622,
#    'top3_accuracy_std': 0.008396374529444821,
#    'row': dataset                         miniImageNet
#    test_dataset               miniImageNet-test
#    n_shot                                     1
#    k                                        0.2
#    aux_rotation_k                             1
#    dfmn_k                                     1
#    is_feat                                 True
#    distance                        cosine_scale
#    test_accuracy                         0.5292
#    test_accuracy_std                  0.0121901
#    test_top_3_accuracy                  0.87272
#    test_top_3_accuracy_std           0.00839637
#    Name: 287, dtype: object}, 'google-landmarks2google-landmarks-test_5shot': {'accuracy': 0.36176,
#    'accuracy_std': 0.0028527284588021435,
#    'top3_accuracy': 0.5228567123413086,
#    'top3_accuracy_std': 0.002968951174590259,
#    'row': dataset                         google-landmarks
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                            0.2
#    aux_rotation_k                                 1
#    dfmn_k                                         1
#    is_feat                                     True
#    distance                            cosine_scale
#    test_accuracy                            0.36176
#    test_accuracy_std                     0.00285273
#    test_top_3_accuracy                     0.522857
#    test_top_3_accuracy_std               0.00296895
#    Name: 206, dtype: object}, 'miniImageNet2google-landmarks-test_5shot': {'accuracy': 0.26634,
#    'accuracy_std': 0.002686010844031397,
#    'top3_accuracy': 0.40618664026260376,
#    'top3_accuracy_std': 0.002930343556680319,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         5
#    k                                            0.2
#    aux_rotation_k                                 1
#    dfmn_k                                         1
#    is_feat                                     True
#    distance                            cosine_scale
#    test_accuracy                            0.26634
#    test_accuracy_std                     0.00268601
#    test_top_3_accuracy                     0.406187
#    test_top_3_accuracy_std               0.00293034
#    Name: 349, dtype: object}, 'miniImageNet2google-landmarks-test_1shot': {'accuracy': 0.14935666666666664,
#    'accuracy_std': 0.0021085590153280343,
#    'top3_accuracy': 0.2418399602174759,
#    'top3_accuracy_std': 0.002495627804690173,
#    'row': dataset                             miniImageNet
#    test_dataset               google-landmarks-test
#    n_shot                                         1
#    k                                            0.2
#    aux_rotation_k                                 1
#    dfmn_k                                         1
#    is_feat                                     True
#    distance                            cosine_scale
#    test_accuracy                           0.149357
#    test_accuracy_std                     0.00210856
#    test_top_3_accuracy                      0.24184
#    test_top_3_accuracy_std               0.00249563
#    Name: 286, dtype: object}}}

# %%
HEADERS = ['Rotation task', 'DFMN', 'FEAT',
           'Distance', 'Accuracy', 'Top-3 accuracy']

# %% [markdown]
# * ## [1-shot] miniImageNet -> miniImageNet (5-way)

# %%
CASE = 'miniImageNet2miniImageNet-test_1shot'

cur_configs = []

for config in configurations:
    metrics = configurations[config]
    cur_configs.append(
        (metrics[CASE]['accuracy'], metrics[CASE]['top3_accuracy'], config))

cur_configs.sort(reverse=True)

table = []

for _, _, config in cur_configs:
    row = configurations[config][CASE]['row']
    table.append((*config, accuracy_repr(row), top3_accuracy_repr(row)))

print(tabulate(table, headers=HEADERS, showindex="always", tablefmt="fancy_grid"))
# Out:
# ╒════╤═════════════════╤════════╤════════╤══════════════════╤══════════════════╤══════════════════╕
# │    │ Rotation task   │ DFMN   │ FEAT   │ Distance         │ Accuracy         │ Top-3 accuracy   │
# ╞════╪═════════════════╪════════╪════════╪══════════════════╪══════════════════╪══════════════════╡
# │  0 │ +               │ -      │ +      │ SEN              │ 0.550 $+-$ 0.013 │ 0.894 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  1 │ +               │ -      │ +      │ Euclidean        │ 0.549 $+-$ 0.012 │ 0.889 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  2 │ -               │ -      │ +      │ SEN              │ 0.548 $+-$ 0.012 │ 0.895 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  3 │ -               │ +      │ +      │ SEN              │ 0.548 $+-$ 0.012 │ 0.894 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  4 │ -               │ +      │ +      │ Euclidean        │ 0.547 $+-$ 0.013 │ 0.889 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  5 │ +               │ -      │ +      │ Scaled euclidean │ 0.546 $+-$ 0.013 │ 0.892 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  6 │ -               │ -      │ +      │ Euclidean        │ 0.546 $+-$ 0.013 │ 0.893 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  7 │ -               │ -      │ +      │ Scaled euclidean │ 0.544 $+-$ 0.012 │ 0.891 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  8 │ +               │ +      │ +      │ Euclidean        │ 0.544 $+-$ 0.012 │ 0.887 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  9 │ -               │ +      │ -      │ Scaled euclidean │ 0.542 $+-$ 0.012 │ 0.888 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 10 │ +               │ +      │ +      │ SEN              │ 0.530 $+-$ 0.012 │ 0.883 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 11 │ -               │ +      │ +      │ Scaled euclidean │ 0.529 $+-$ 0.012 │ 0.881 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 12 │ +               │ +      │ +      │ Scaled euclidean │ 0.529 $+-$ 0.012 │ 0.873 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 13 │ -               │ +      │ -      │ Euclidean        │ 0.526 $+-$ 0.012 │ 0.881 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 14 │ +               │ -      │ -      │ Scaled euclidean │ 0.526 $+-$ 0.012 │ 0.878 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 15 │ +               │ +      │ -      │ Scaled euclidean │ 0.525 $+-$ 0.012 │ 0.877 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 16 │ -               │ -      │ -      │ Scaled euclidean │ 0.520 $+-$ 0.012 │ 0.875 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 17 │ -               │ +      │ -      │ SEN              │ 0.519 $+-$ 0.012 │ 0.876 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 18 │ +               │ +      │ -      │ SEN              │ 0.510 $+-$ 0.012 │ 0.871 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 19 │ +               │ -      │ -      │ SEN              │ 0.510 $+-$ 0.012 │ 0.877 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 20 │ +               │ +      │ -      │ Euclidean        │ 0.509 $+-$ 0.012 │ 0.869 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 21 │ +               │ -      │ -      │ Euclidean        │ 0.509 $+-$ 0.012 │ 0.870 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 22 │ -               │ -      │ -      │ SEN              │ 0.508 $+-$ 0.012 │ 0.872 $+-$ 0.008 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 23 │ -               │ -      │ -      │ Euclidean        │ 0.501 $+-$ 0.012 │ 0.871 $+-$ 0.008 │
# ╘════╧═════════════════╧════════╧════════╧══════════════════╧══════════════════╧══════════════════╛

# %%
print(tabulate_bold(table, headers=HEADERS, showindex=range(1, len(table) + 1), tablefmt="latex").replace('+-', '\pm').replace('\\$', '$'))
# Out:
# \begin{tabular}{rllllll}
# \hline
#     & Rotation task   & DFMN   & FEAT   & Distance         & Accuracy         & Top-3 accuracy   \\
# \hline
# \textbf{1} & \textbf{+} & \textbf{-} & \textbf{+} & \textbf{SEN} & \textbf{0.550} $\pm$ \textbf{0.013} & \textbf{0.894} $\pm$ \textbf{0.008} \\
#   2 & +               & -      & +      & Euclidean        & 0.549 $\pm$ 0.012 & 0.889 $\pm$ 0.008 \\
#   3 & -               & -      & +      & SEN              & 0.548 $\pm$ 0.012 & 0.895 $\pm$ 0.008 \\
#   4 & -               & +      & +      & SEN              & 0.548 $\pm$ 0.012 & 0.894 $\pm$ 0.008 \\
#   5 & -               & +      & +      & Euclidean        & 0.547 $\pm$ 0.013 & 0.889 $\pm$ 0.008 \\
#   6 & +               & -      & +      & Scaled euclidean & 0.546 $\pm$ 0.013 & 0.892 $\pm$ 0.008 \\
#   7 & -               & -      & +      & Euclidean        & 0.546 $\pm$ 0.013 & 0.893 $\pm$ 0.008 \\
#   8 & -               & -      & +      & Scaled euclidean & 0.544 $\pm$ 0.012 & 0.891 $\pm$ 0.008 \\
#   9 & +               & +      & +      & Euclidean        & 0.544 $\pm$ 0.012 & 0.887 $\pm$ 0.008 \\
#  10 & -               & +      & -      & Scaled euclidean & 0.542 $\pm$ 0.012 & 0.888 $\pm$ 0.008 \\
#  11 & +               & +      & +      & SEN              & 0.530 $\pm$ 0.012 & 0.883 $\pm$ 0.008 \\
#  12 & -               & +      & +      & Scaled euclidean & 0.529 $\pm$ 0.012 & 0.881 $\pm$ 0.008 \\
#  13 & +               & +      & +      & Scaled euclidean & 0.529 $\pm$ 0.012 & 0.873 $\pm$ 0.008 \\
#  14 & -               & +      & -      & Euclidean        & 0.526 $\pm$ 0.012 & 0.881 $\pm$ 0.008 \\
#  15 & +               & -      & -      & Scaled euclidean & 0.526 $\pm$ 0.012 & 0.878 $\pm$ 0.008 \\
#  16 & +               & +      & -      & Scaled euclidean & 0.525 $\pm$ 0.012 & 0.877 $\pm$ 0.008 \\
#  17 & -               & -      & -      & Scaled euclidean & 0.520 $\pm$ 0.012 & 0.875 $\pm$ 0.008 \\
#  18 & -               & +      & -      & SEN              & 0.519 $\pm$ 0.012 & 0.876 $\pm$ 0.008 \\
#  19 & +               & +      & -      & SEN              & 0.510 $\pm$ 0.012 & 0.871 $\pm$ 0.008 \\
#  20 & +               & -      & -      & SEN              & 0.510 $\pm$ 0.012 & 0.877 $\pm$ 0.008 \\
#  21 & +               & +      & -      & Euclidean        & 0.509 $\pm$ 0.012 & 0.869 $\pm$ 0.008 \\
#  22 & +               & -      & -      & Euclidean        & 0.509 $\pm$ 0.012 & 0.870 $\pm$ 0.008 \\
#  23 & -               & -      & -      & SEN              & 0.508 $\pm$ 0.012 & 0.872 $\pm$ 0.008 \\
#  24 & -               & -      & -      & Euclidean        & 0.501 $\pm$ 0.012 & 0.871 $\pm$ 0.008 \\
# \hline
# \end{tabular}

# %% [markdown]
# * ## [5-shot] miniImageNet -> miniImageNet (5-way)

# %%
CASE = 'miniImageNet2miniImageNet-test_5shot'

cur_configs = []

for config in configurations:
    metrics = configurations[config]
    cur_configs.append(
        (metrics[CASE]['accuracy'], metrics[CASE]['top3_accuracy'], config))

cur_configs.sort(reverse=True)

table = []

for _, _, config in cur_configs:
    row = configurations[config][CASE]['row']
    table.append((*config, accuracy_repr(row), top3_accuracy_repr(row)))

print(tabulate(table, headers=HEADERS, showindex="always", tablefmt="fancy_grid"))
# Out:
# ╒════╤═════════════════╤════════╤════════╤══════════════════╤══════════════════╤══════════════════╕
# │    │ Rotation task   │ DFMN   │ FEAT   │ Distance         │ Accuracy         │ Top-3 accuracy   │
# ╞════╪═════════════════╪════════╪════════╪══════════════════╪══════════════════╪══════════════════╡
# │  0 │ -               │ +      │ -      │ Scaled euclidean │ 0.703 $+-$ 0.011 │ 0.955 $+-$ 0.004 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  1 │ +               │ -      │ +      │ Euclidean        │ 0.700 $+-$ 0.011 │ 0.954 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  2 │ +               │ -      │ +      │ Scaled euclidean │ 0.700 $+-$ 0.011 │ 0.953 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  3 │ -               │ +      │ -      │ SEN              │ 0.697 $+-$ 0.011 │ 0.950 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  4 │ -               │ +      │ -      │ Euclidean        │ 0.696 $+-$ 0.011 │ 0.951 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  5 │ -               │ -      │ +      │ Euclidean        │ 0.694 $+-$ 0.011 │ 0.950 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  6 │ +               │ -      │ +      │ SEN              │ 0.693 $+-$ 0.011 │ 0.951 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  7 │ -               │ +      │ +      │ Euclidean        │ 0.692 $+-$ 0.011 │ 0.952 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  8 │ -               │ +      │ +      │ SEN              │ 0.690 $+-$ 0.011 │ 0.951 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  9 │ +               │ +      │ -      │ Scaled euclidean │ 0.690 $+-$ 0.011 │ 0.950 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 10 │ +               │ -      │ -      │ SEN              │ 0.688 $+-$ 0.011 │ 0.947 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 11 │ +               │ -      │ -      │ Euclidean        │ 0.686 $+-$ 0.011 │ 0.947 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 12 │ -               │ -      │ +      │ SEN              │ 0.685 $+-$ 0.011 │ 0.949 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 13 │ -               │ +      │ +      │ Scaled euclidean │ 0.685 $+-$ 0.011 │ 0.949 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 14 │ +               │ +      │ +      │ SEN              │ 0.684 $+-$ 0.011 │ 0.949 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 15 │ +               │ +      │ +      │ Euclidean        │ 0.683 $+-$ 0.011 │ 0.948 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 16 │ +               │ +      │ -      │ SEN              │ 0.680 $+-$ 0.011 │ 0.947 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 17 │ -               │ -      │ -      │ SEN              │ 0.679 $+-$ 0.011 │ 0.946 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 18 │ +               │ +      │ -      │ Euclidean        │ 0.678 $+-$ 0.011 │ 0.947 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 19 │ +               │ -      │ -      │ Scaled euclidean │ 0.678 $+-$ 0.011 │ 0.945 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 20 │ -               │ -      │ -      │ Scaled euclidean │ 0.677 $+-$ 0.011 │ 0.947 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 21 │ -               │ -      │ -      │ Euclidean        │ 0.677 $+-$ 0.011 │ 0.945 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 22 │ -               │ -      │ +      │ Scaled euclidean │ 0.669 $+-$ 0.012 │ 0.943 $+-$ 0.005 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 23 │ +               │ +      │ +      │ Scaled euclidean │ 0.654 $+-$ 0.011 │ 0.932 $+-$ 0.006 │
# ╘════╧═════════════════╧════════╧════════╧══════════════════╧══════════════════╧══════════════════╛

# %%
print(tabulate_bold(table, headers=HEADERS, showindex=range(1, len(table) + 1), tablefmt="latex").replace('+-', '\pm').replace('\\$', '$'))
# Out:
# \begin{tabular}{rllllll}
# \hline
#     & Rotation task   & DFMN   & FEAT   & Distance         & Accuracy         & Top-3 accuracy   \\
# \hline
# \textbf{1} & \textbf{-} & \textbf{+} & \textbf{-} & \textbf{Scaled} \textbf{euclidean} & \textbf{0.703} $\pm$ \textbf{0.011} & \textbf{0.955} $\pm$ \textbf{0.004} \\
#   2 & +               & -      & +      & Euclidean        & 0.700 $\pm$ 0.011 & 0.954 $\pm$ 0.005 \\
#   3 & +               & -      & +      & Scaled euclidean & 0.700 $\pm$ 0.011 & 0.953 $\pm$ 0.005 \\
#   4 & -               & +      & -      & SEN              & 0.697 $\pm$ 0.011 & 0.950 $\pm$ 0.005 \\
#   5 & -               & +      & -      & Euclidean        & 0.696 $\pm$ 0.011 & 0.951 $\pm$ 0.005 \\
#   6 & -               & -      & +      & Euclidean        & 0.694 $\pm$ 0.011 & 0.950 $\pm$ 0.005 \\
#   7 & +               & -      & +      & SEN              & 0.693 $\pm$ 0.011 & 0.951 $\pm$ 0.005 \\
#   8 & -               & +      & +      & Euclidean        & 0.692 $\pm$ 0.011 & 0.952 $\pm$ 0.005 \\
#   9 & -               & +      & +      & SEN              & 0.690 $\pm$ 0.011 & 0.951 $\pm$ 0.005 \\
#  10 & +               & +      & -      & Scaled euclidean & 0.690 $\pm$ 0.011 & 0.950 $\pm$ 0.005 \\
#  11 & +               & -      & -      & SEN              & 0.688 $\pm$ 0.011 & 0.947 $\pm$ 0.005 \\
#  12 & +               & -      & -      & Euclidean        & 0.686 $\pm$ 0.011 & 0.947 $\pm$ 0.005 \\
#  13 & -               & -      & +      & SEN              & 0.685 $\pm$ 0.011 & 0.949 $\pm$ 0.005 \\
#  14 & -               & +      & +      & Scaled euclidean & 0.685 $\pm$ 0.011 & 0.949 $\pm$ 0.005 \\
#  15 & +               & +      & +      & SEN              & 0.684 $\pm$ 0.011 & 0.949 $\pm$ 0.005 \\
#  16 & +               & +      & +      & Euclidean        & 0.683 $\pm$ 0.011 & 0.948 $\pm$ 0.005 \\
#  17 & +               & +      & -      & SEN              & 0.680 $\pm$ 0.011 & 0.947 $\pm$ 0.005 \\
#  18 & -               & -      & -      & SEN              & 0.679 $\pm$ 0.011 & 0.946 $\pm$ 0.005 \\
#  19 & +               & +      & -      & Euclidean        & 0.678 $\pm$ 0.011 & 0.947 $\pm$ 0.005 \\
#  20 & +               & -      & -      & Scaled euclidean & 0.678 $\pm$ 0.011 & 0.945 $\pm$ 0.005 \\
#  21 & -               & -      & -      & Scaled euclidean & 0.677 $\pm$ 0.011 & 0.947 $\pm$ 0.005 \\
#  22 & -               & -      & -      & Euclidean        & 0.677 $\pm$ 0.011 & 0.945 $\pm$ 0.005 \\
#  23 & -               & -      & +      & Scaled euclidean & 0.669 $\pm$ 0.012 & 0.943 $\pm$ 0.005 \\
#  24 & +               & +      & +      & Scaled euclidean & 0.654 $\pm$ 0.011 & 0.932 $\pm$ 0.006 \\
# \hline
# \end{tabular}

# %% [markdown]
# * ## [5-shot] miniImageNet -> googleLandmarks (100-way)

# %%
CASE = 'miniImageNet2google-landmarks-test_5shot'

cur_configs = []

for config in configurations:
    metrics = configurations[config]
    cur_configs.append(
        (metrics[CASE]['accuracy'], metrics[CASE]['top3_accuracy'], config))

cur_configs.sort(reverse=True)

table = []

for _, _, config in cur_configs:
    row = configurations[config][CASE]['row']
    table.append((*config, accuracy_repr(row), top3_accuracy_repr(row)))

print(tabulate(table, headers=HEADERS, showindex="always", tablefmt="fancy_grid"))
# Out:
# ╒════╤═════════════════╤════════╤════════╤══════════════════╤══════════════════╤══════════════════╕
# │    │ Rotation task   │ DFMN   │ FEAT   │ Distance         │ Accuracy         │ Top-3 accuracy   │
# ╞════╪═════════════════╪════════╪════════╪══════════════════╪══════════════════╪══════════════════╡
# │  0 │ -               │ +      │ -      │ Scaled euclidean │ 0.298 $+-$ 0.003 │ 0.442 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  1 │ +               │ +      │ -      │ Scaled euclidean │ 0.296 $+-$ 0.003 │ 0.441 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  2 │ -               │ +      │ -      │ Euclidean        │ 0.295 $+-$ 0.003 │ 0.436 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  3 │ +               │ +      │ -      │ Euclidean        │ 0.291 $+-$ 0.003 │ 0.434 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  4 │ +               │ +      │ -      │ SEN              │ 0.291 $+-$ 0.003 │ 0.433 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  5 │ -               │ +      │ -      │ SEN              │ 0.288 $+-$ 0.003 │ 0.432 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  6 │ +               │ +      │ +      │ Euclidean        │ 0.285 $+-$ 0.003 │ 0.428 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  7 │ +               │ +      │ +      │ SEN              │ 0.285 $+-$ 0.003 │ 0.429 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  8 │ -               │ +      │ +      │ Euclidean        │ 0.285 $+-$ 0.003 │ 0.427 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  9 │ -               │ +      │ +      │ SEN              │ 0.283 $+-$ 0.003 │ 0.427 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 10 │ -               │ +      │ +      │ Scaled euclidean │ 0.275 $+-$ 0.003 │ 0.415 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 11 │ +               │ +      │ +      │ Scaled euclidean │ 0.266 $+-$ 0.003 │ 0.406 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 12 │ +               │ -      │ -      │ SEN              │ 0.261 $+-$ 0.003 │ 0.399 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 13 │ +               │ -      │ +      │ Scaled euclidean │ 0.259 $+-$ 0.003 │ 0.397 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 14 │ +               │ -      │ -      │ Euclidean        │ 0.258 $+-$ 0.003 │ 0.395 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 15 │ +               │ -      │ -      │ Scaled euclidean │ 0.254 $+-$ 0.003 │ 0.390 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 16 │ +               │ -      │ +      │ SEN              │ 0.253 $+-$ 0.003 │ 0.391 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 17 │ +               │ -      │ +      │ Euclidean        │ 0.251 $+-$ 0.003 │ 0.388 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 18 │ -               │ -      │ -      │ Euclidean        │ 0.250 $+-$ 0.003 │ 0.388 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 19 │ -               │ -      │ -      │ SEN              │ 0.246 $+-$ 0.003 │ 0.382 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 20 │ -               │ -      │ +      │ Euclidean        │ 0.235 $+-$ 0.003 │ 0.371 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 21 │ -               │ -      │ +      │ SEN              │ 0.233 $+-$ 0.003 │ 0.367 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 22 │ -               │ -      │ -      │ Scaled euclidean │ 0.221 $+-$ 0.002 │ 0.351 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 23 │ -               │ -      │ +      │ Scaled euclidean │ 0.215 $+-$ 0.002 │ 0.347 $+-$ 0.003 │
# ╘════╧═════════════════╧════════╧════════╧══════════════════╧══════════════════╧══════════════════╛

# %%
print(tabulate_bold(table, headers=HEADERS, showindex=range(1, len(table) + 1), tablefmt="latex").replace('+-', '\pm').replace('\\$', '$'))
# Out:
# \begin{tabular}{rllllll}
# \hline
#     & Rotation task   & DFMN   & FEAT   & Distance         & Accuracy         & Top-3 accuracy   \\
# \hline
# \textbf{1} & \textbf{-} & \textbf{+} & \textbf{-} & \textbf{Scaled} \textbf{euclidean} & \textbf{0.298} $\pm$ \textbf{0.003} & \textbf{0.442} $\pm$ \textbf{0.003} \\
#   2 & +               & +      & -      & Scaled euclidean & 0.296 $\pm$ 0.003 & 0.441 $\pm$ 0.003 \\
#   3 & -               & +      & -      & Euclidean        & 0.295 $\pm$ 0.003 & 0.436 $\pm$ 0.003 \\
#   4 & +               & +      & -      & Euclidean        & 0.291 $\pm$ 0.003 & 0.434 $\pm$ 0.003 \\
#   5 & +               & +      & -      & SEN              & 0.291 $\pm$ 0.003 & 0.433 $\pm$ 0.003 \\
#   6 & -               & +      & -      & SEN              & 0.288 $\pm$ 0.003 & 0.432 $\pm$ 0.003 \\
#   7 & +               & +      & +      & Euclidean        & 0.285 $\pm$ 0.003 & 0.428 $\pm$ 0.003 \\
#   8 & +               & +      & +      & SEN              & 0.285 $\pm$ 0.003 & 0.429 $\pm$ 0.003 \\
#   9 & -               & +      & +      & Euclidean        & 0.285 $\pm$ 0.003 & 0.427 $\pm$ 0.003 \\
#  10 & -               & +      & +      & SEN              & 0.283 $\pm$ 0.003 & 0.427 $\pm$ 0.003 \\
#  11 & -               & +      & +      & Scaled euclidean & 0.275 $\pm$ 0.003 & 0.415 $\pm$ 0.003 \\
#  12 & +               & +      & +      & Scaled euclidean & 0.266 $\pm$ 0.003 & 0.406 $\pm$ 0.003 \\
#  13 & +               & -      & -      & SEN              & 0.261 $\pm$ 0.003 & 0.399 $\pm$ 0.003 \\
#  14 & +               & -      & +      & Scaled euclidean & 0.259 $\pm$ 0.003 & 0.397 $\pm$ 0.003 \\
#  15 & +               & -      & -      & Euclidean        & 0.258 $\pm$ 0.003 & 0.395 $\pm$ 0.003 \\
#  16 & +               & -      & -      & Scaled euclidean & 0.254 $\pm$ 0.003 & 0.390 $\pm$ 0.003 \\
#  17 & +               & -      & +      & SEN              & 0.253 $\pm$ 0.003 & 0.391 $\pm$ 0.003 \\
#  18 & +               & -      & +      & Euclidean        & 0.251 $\pm$ 0.003 & 0.388 $\pm$ 0.003 \\
#  19 & -               & -      & -      & Euclidean        & 0.250 $\pm$ 0.003 & 0.388 $\pm$ 0.003 \\
#  20 & -               & -      & -      & SEN              & 0.246 $\pm$ 0.003 & 0.382 $\pm$ 0.003 \\
#  21 & -               & -      & +      & Euclidean        & 0.235 $\pm$ 0.003 & 0.371 $\pm$ 0.003 \\
#  22 & -               & -      & +      & SEN              & 0.233 $\pm$ 0.003 & 0.367 $\pm$ 0.003 \\
#  23 & -               & -      & -      & Scaled euclidean & 0.221 $\pm$ 0.002 & 0.351 $\pm$ 0.003 \\
#  24 & -               & -      & +      & Scaled euclidean & 0.215 $\pm$ 0.002 & 0.347 $\pm$ 0.003 \\
# \hline
# \end{tabular}

# %% [markdown]
# * ## [5-shot] googleLandmarks -> miniImageNet (5-way)

# %%
CASE = 'google-landmarks2miniImageNet-test_5shot'

cur_configs = []

for config in configurations:
    metrics = configurations[config]
    cur_configs.append(
        (metrics[CASE]['accuracy'], metrics[CASE]['top3_accuracy'], config))

cur_configs.sort(reverse=True)

table = []

for _, _, config in cur_configs:
    row = configurations[config][CASE]['row']
    table.append((*config, accuracy_repr(row), top3_accuracy_repr(row)))

print(tabulate(table, headers=HEADERS, showindex="always", tablefmt="fancy_grid"))
# Out:
# ╒════╤═════════════════╤════════╤════════╤══════════════════╤══════════════════╤══════════════════╕
# │    │ Rotation task   │ DFMN   │ FEAT   │ Distance         │ Accuracy         │ Top-3 accuracy   │
# ╞════╪═════════════════╪════════╪════════╪══════════════════╪══════════════════╪══════════════════╡
# │  0 │ +               │ -      │ +      │ Euclidean        │ 0.562 $+-$ 0.011 │ 0.897 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  1 │ -               │ -      │ +      │ Euclidean        │ 0.562 $+-$ 0.011 │ 0.896 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  2 │ +               │ -      │ -      │ SEN              │ 0.561 $+-$ 0.012 │ 0.897 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  3 │ -               │ -      │ -      │ Euclidean        │ 0.561 $+-$ 0.011 │ 0.895 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  4 │ +               │ +      │ -      │ SEN              │ 0.558 $+-$ 0.012 │ 0.894 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  5 │ -               │ +      │ -      │ Euclidean        │ 0.557 $+-$ 0.012 │ 0.891 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  6 │ +               │ -      │ -      │ Euclidean        │ 0.557 $+-$ 0.012 │ 0.898 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  7 │ +               │ -      │ +      │ SEN              │ 0.556 $+-$ 0.011 │ 0.891 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  8 │ +               │ +      │ -      │ Euclidean        │ 0.556 $+-$ 0.012 │ 0.890 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  9 │ -               │ +      │ -      │ SEN              │ 0.555 $+-$ 0.011 │ 0.892 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 10 │ +               │ -      │ +      │ Scaled euclidean │ 0.555 $+-$ 0.011 │ 0.892 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 11 │ +               │ -      │ -      │ Scaled euclidean │ 0.555 $+-$ 0.011 │ 0.892 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 12 │ -               │ -      │ +      │ SEN              │ 0.554 $+-$ 0.012 │ 0.894 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 13 │ +               │ +      │ -      │ Scaled euclidean │ 0.550 $+-$ 0.012 │ 0.890 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 14 │ +               │ +      │ +      │ Euclidean        │ 0.550 $+-$ 0.012 │ 0.888 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 15 │ -               │ -      │ -      │ SEN              │ 0.549 $+-$ 0.011 │ 0.889 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 16 │ -               │ +      │ +      │ SEN              │ 0.546 $+-$ 0.011 │ 0.885 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 17 │ -               │ -      │ +      │ Scaled euclidean │ 0.545 $+-$ 0.011 │ 0.890 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 18 │ +               │ +      │ +      │ SEN              │ 0.544 $+-$ 0.012 │ 0.885 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 19 │ +               │ +      │ +      │ Scaled euclidean │ 0.541 $+-$ 0.012 │ 0.885 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 20 │ -               │ +      │ -      │ Scaled euclidean │ 0.541 $+-$ 0.012 │ 0.888 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 21 │ -               │ +      │ +      │ Euclidean        │ 0.541 $+-$ 0.011 │ 0.884 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 22 │ -               │ +      │ +      │ Scaled euclidean │ 0.541 $+-$ 0.011 │ 0.885 $+-$ 0.007 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 23 │ -               │ -      │ -      │ Scaled euclidean │ 0.536 $+-$ 0.011 │ 0.881 $+-$ 0.007 │
# ╘════╧═════════════════╧════════╧════════╧══════════════════╧══════════════════╧══════════════════╛

# %%
print(tabulate_bold(table, headers=HEADERS, showindex=range(1, len(table) + 1), tablefmt="latex").replace('+-', '\pm').replace('\\$', '$'))
# Out:
# \begin{tabular}{rllllll}
# \hline
#     & Rotation task   & DFMN   & FEAT   & Distance         & Accuracy         & Top-3 accuracy   \\
# \hline
# \textbf{1} & \textbf{+} & \textbf{-} & \textbf{+} & \textbf{Euclidean} & \textbf{0.562} $\pm$ \textbf{0.011} & \textbf{0.897} $\pm$ \textbf{0.007} \\
#   2 & -               & -      & +      & Euclidean        & 0.562 $\pm$ 0.011 & 0.896 $\pm$ 0.007 \\
#   3 & +               & -      & -      & SEN              & 0.561 $\pm$ 0.012 & 0.897 $\pm$ 0.007 \\
#   4 & -               & -      & -      & Euclidean        & 0.561 $\pm$ 0.011 & 0.895 $\pm$ 0.007 \\
#   5 & +               & +      & -      & SEN              & 0.558 $\pm$ 0.012 & 0.894 $\pm$ 0.007 \\
#   6 & -               & +      & -      & Euclidean        & 0.557 $\pm$ 0.012 & 0.891 $\pm$ 0.007 \\
#   7 & +               & -      & -      & Euclidean        & 0.557 $\pm$ 0.012 & 0.898 $\pm$ 0.007 \\
#   8 & +               & -      & +      & SEN              & 0.556 $\pm$ 0.011 & 0.891 $\pm$ 0.007 \\
#   9 & +               & +      & -      & Euclidean        & 0.556 $\pm$ 0.012 & 0.890 $\pm$ 0.007 \\
#  10 & -               & +      & -      & SEN              & 0.555 $\pm$ 0.011 & 0.892 $\pm$ 0.007 \\
#  11 & +               & -      & +      & Scaled euclidean & 0.555 $\pm$ 0.011 & 0.892 $\pm$ 0.007 \\
#  12 & +               & -      & -      & Scaled euclidean & 0.555 $\pm$ 0.011 & 0.892 $\pm$ 0.007 \\
#  13 & -               & -      & +      & SEN              & 0.554 $\pm$ 0.012 & 0.894 $\pm$ 0.007 \\
#  14 & +               & +      & -      & Scaled euclidean & 0.550 $\pm$ 0.012 & 0.890 $\pm$ 0.007 \\
#  15 & +               & +      & +      & Euclidean        & 0.550 $\pm$ 0.012 & 0.888 $\pm$ 0.007 \\
#  16 & -               & -      & -      & SEN              & 0.549 $\pm$ 0.011 & 0.889 $\pm$ 0.007 \\
#  17 & -               & +      & +      & SEN              & 0.546 $\pm$ 0.011 & 0.885 $\pm$ 0.007 \\
#  18 & -               & -      & +      & Scaled euclidean & 0.545 $\pm$ 0.011 & 0.890 $\pm$ 0.007 \\
#  19 & +               & +      & +      & SEN              & 0.544 $\pm$ 0.012 & 0.885 $\pm$ 0.007 \\
#  20 & +               & +      & +      & Scaled euclidean & 0.541 $\pm$ 0.012 & 0.885 $\pm$ 0.007 \\
#  21 & -               & +      & -      & Scaled euclidean & 0.541 $\pm$ 0.012 & 0.888 $\pm$ 0.007 \\
#  22 & -               & +      & +      & Euclidean        & 0.541 $\pm$ 0.011 & 0.884 $\pm$ 0.007 \\
#  23 & -               & +      & +      & Scaled euclidean & 0.541 $\pm$ 0.011 & 0.885 $\pm$ 0.007 \\
#  24 & -               & -      & -      & Scaled euclidean & 0.536 $\pm$ 0.011 & 0.881 $\pm$ 0.007 \\
# \hline
# \end{tabular}

# %% [markdown]
# * ## [5-shot] googleLandmarks -> googleLandmarks (100-way)

# %%
CASE = 'google-landmarks2google-landmarks-test_5shot'

cur_configs = []

for config in configurations:
    metrics = configurations[config]
    cur_configs.append(
        (metrics[CASE]['accuracy'], metrics[CASE]['top3_accuracy'], config))

cur_configs.sort(reverse=True)

table = []

for _, _, config in cur_configs:
    row = configurations[config][CASE]['row']
    table.append((*config, accuracy_repr(row), top3_accuracy_repr(row)))

print(tabulate(table, headers=HEADERS, showindex="always", tablefmt="fancy_grid"))
# Out:
# ╒════╤═════════════════╤════════╤════════╤══════════════════╤══════════════════╤══════════════════╕
# │    │ Rotation task   │ DFMN   │ FEAT   │ Distance         │ Accuracy         │ Top-3 accuracy   │
# ╞════╪═════════════════╪════════╪════════╪══════════════════╪══════════════════╪══════════════════╡
# │  0 │ -               │ -      │ +      │ Euclidean        │ 0.403 $+-$ 0.003 │ 0.565 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  1 │ -               │ +      │ -      │ Euclidean        │ 0.398 $+-$ 0.003 │ 0.555 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  2 │ +               │ -      │ +      │ Euclidean        │ 0.398 $+-$ 0.003 │ 0.559 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  3 │ +               │ -      │ +      │ SEN              │ 0.397 $+-$ 0.003 │ 0.558 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  4 │ -               │ -      │ -      │ SEN              │ 0.395 $+-$ 0.003 │ 0.556 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  5 │ -               │ -      │ +      │ SEN              │ 0.395 $+-$ 0.003 │ 0.558 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  6 │ +               │ -      │ -      │ Euclidean        │ 0.392 $+-$ 0.003 │ 0.551 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  7 │ +               │ -      │ -      │ SEN              │ 0.390 $+-$ 0.003 │ 0.549 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  8 │ -               │ -      │ -      │ Euclidean        │ 0.390 $+-$ 0.003 │ 0.549 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │  9 │ +               │ -      │ +      │ Scaled euclidean │ 0.389 $+-$ 0.003 │ 0.546 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 10 │ -               │ +      │ -      │ SEN              │ 0.389 $+-$ 0.003 │ 0.549 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 11 │ +               │ +      │ -      │ SEN              │ 0.386 $+-$ 0.003 │ 0.544 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 12 │ +               │ +      │ -      │ Euclidean        │ 0.386 $+-$ 0.003 │ 0.540 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 13 │ -               │ -      │ +      │ Scaled euclidean │ 0.385 $+-$ 0.003 │ 0.544 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 14 │ +               │ -      │ -      │ Scaled euclidean │ 0.382 $+-$ 0.003 │ 0.539 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 15 │ -               │ -      │ -      │ Scaled euclidean │ 0.376 $+-$ 0.003 │ 0.532 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 16 │ +               │ +      │ +      │ Euclidean        │ 0.376 $+-$ 0.003 │ 0.537 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 17 │ -               │ +      │ -      │ Scaled euclidean │ 0.375 $+-$ 0.003 │ 0.537 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 18 │ -               │ +      │ +      │ SEN              │ 0.372 $+-$ 0.003 │ 0.534 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 19 │ -               │ +      │ +      │ Scaled euclidean │ 0.372 $+-$ 0.003 │ 0.533 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 20 │ -               │ +      │ +      │ Euclidean        │ 0.372 $+-$ 0.003 │ 0.533 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 21 │ +               │ +      │ -      │ Scaled euclidean │ 0.369 $+-$ 0.003 │ 0.530 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 22 │ +               │ +      │ +      │ SEN              │ 0.365 $+-$ 0.003 │ 0.526 $+-$ 0.003 │
# ├────┼─────────────────┼────────┼────────┼──────────────────┼──────────────────┼──────────────────┤
# │ 23 │ +               │ +      │ +      │ Scaled euclidean │ 0.362 $+-$ 0.003 │ 0.523 $+-$ 0.003 │
# ╘════╧═════════════════╧════════╧════════╧══════════════════╧══════════════════╧══════════════════╛

# %%
print(tabulate_bold(table, headers=HEADERS, showindex=range(1, len(table) + 1), tablefmt="latex").replace('+-', '\pm').replace('\\$', '$'))
# Out:
# \begin{tabular}{rllllll}
# \hline
#     & Rotation task   & DFMN   & FEAT   & Distance         & Accuracy         & Top-3 accuracy   \\
# \hline
# \textbf{1} & \textbf{-} & \textbf{-} & \textbf{+} & \textbf{Euclidean} & \textbf{0.403} $\pm$ \textbf{0.003} & \textbf{0.565} $\pm$ \textbf{0.003} \\
#   2 & -               & +      & -      & Euclidean        & 0.398 $\pm$ 0.003 & 0.555 $\pm$ 0.003 \\
#   3 & +               & -      & +      & Euclidean        & 0.398 $\pm$ 0.003 & 0.559 $\pm$ 0.003 \\
#   4 & +               & -      & +      & SEN              & 0.397 $\pm$ 0.003 & 0.558 $\pm$ 0.003 \\
#   5 & -               & -      & -      & SEN              & 0.395 $\pm$ 0.003 & 0.556 $\pm$ 0.003 \\
#   6 & -               & -      & +      & SEN              & 0.395 $\pm$ 0.003 & 0.558 $\pm$ 0.003 \\
#   7 & +               & -      & -      & Euclidean        & 0.392 $\pm$ 0.003 & 0.551 $\pm$ 0.003 \\
#   8 & +               & -      & -      & SEN              & 0.390 $\pm$ 0.003 & 0.549 $\pm$ 0.003 \\
#   9 & -               & -      & -      & Euclidean        & 0.390 $\pm$ 0.003 & 0.549 $\pm$ 0.003 \\
#  10 & +               & -      & +      & Scaled euclidean & 0.389 $\pm$ 0.003 & 0.546 $\pm$ 0.003 \\
#  11 & -               & +      & -      & SEN              & 0.389 $\pm$ 0.003 & 0.549 $\pm$ 0.003 \\
#  12 & +               & +      & -      & SEN              & 0.386 $\pm$ 0.003 & 0.544 $\pm$ 0.003 \\
#  13 & +               & +      & -      & Euclidean        & 0.386 $\pm$ 0.003 & 0.540 $\pm$ 0.003 \\
#  14 & -               & -      & +      & Scaled euclidean & 0.385 $\pm$ 0.003 & 0.544 $\pm$ 0.003 \\
#  15 & +               & -      & -      & Scaled euclidean & 0.382 $\pm$ 0.003 & 0.539 $\pm$ 0.003 \\
#  16 & -               & -      & -      & Scaled euclidean & 0.376 $\pm$ 0.003 & 0.532 $\pm$ 0.003 \\
#  17 & +               & +      & +      & Euclidean        & 0.376 $\pm$ 0.003 & 0.537 $\pm$ 0.003 \\
#  18 & -               & +      & -      & Scaled euclidean & 0.375 $\pm$ 0.003 & 0.537 $\pm$ 0.003 \\
#  19 & -               & +      & +      & SEN              & 0.372 $\pm$ 0.003 & 0.534 $\pm$ 0.003 \\
#  20 & -               & +      & +      & Scaled euclidean & 0.372 $\pm$ 0.003 & 0.533 $\pm$ 0.003 \\
#  21 & -               & +      & +      & Euclidean        & 0.372 $\pm$ 0.003 & 0.533 $\pm$ 0.003 \\
#  22 & +               & +      & -      & Scaled euclidean & 0.369 $\pm$ 0.003 & 0.530 $\pm$ 0.003 \\
#  23 & +               & +      & +      & SEN              & 0.365 $\pm$ 0.003 & 0.526 $\pm$ 0.003 \\
#  24 & +               & +      & +      & Scaled euclidean & 0.362 $\pm$ 0.003 & 0.523 $\pm$ 0.003 \\
# \hline
# \end{tabular}
