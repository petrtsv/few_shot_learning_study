# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
INDEX_FILE = r'D:\petrtsv\projects\ds\few_shot_learning_study\index.csv'

records = pd.read_csv(INDEX_FILE, index_col=0)
records = records[
    (records['version'].isin({
        '1.0.6', '1.0.7', '1.0.8'
    }))
]

records = records[records['is_test'] == True]

records.columns
# Out:
# Index(['Name', 'Explanation', 'n_iterations', 'n_way', 'n_shot', 'batch_size',
#        'eval_period', 'eval_iterations', 'time', 'accuracy', 'iteration',
#        'result_directory', 'image_size', 'backbone', 'aux_location_k',
#        'aux_rotation_k', 'dataset', 'train_classes', 'test_n_iterations',
#        'dfmn_k', 'distance', 'k', 'test_batch_size', 'test_dataset',
#        'test_n_way', 'test_accuracy', 'testing_time', 'accuracy_std',
#        'top_3_accuracy', 'top_3_accuracy_std', 'test_accuracy_std',
#        'test_top_3_accuracy', 'test_top_3_accuracy_std', 'version', 'is_test',
#        'test_balanced'],
#       dtype='object')

# %%
COLUMNS = ['dataset', 'test_dataset', 'n_shot', 'k', 'aux_rotation_k', 'dfmn_k', 'distance', 'test_accuracy', 'test_top_3_accuracy']
records = records[COLUMNS].sort_values(by='test_accuracy', ascending=False)
# records.head()

# %% [markdown]
# ## MiniImageNet -> MiniImageNet

# %%
records_miniImageNet_miniImageNet = records[(records['dataset'] == 'miniImageNet') &  (records['test_dataset'] == 'miniImageNet-test')]
records_miniImageNet_miniImageNet
# Out:
#           dataset       test_dataset  n_shot    k  aux_rotation_k  dfmn_k  \
# \t
# 102  miniImageNet  miniImageNet-test     1.0  0.2             0.0     1.0
# 124  miniImageNet  miniImageNet-test     1.0  0.2             0.0     1.0
# 105  miniImageNet  miniImageNet-test     1.0  0.2             0.0     1.0
# 96   miniImageNet  miniImageNet-test     1.0  1.0             1.0     0.0
# 111  miniImageNet  miniImageNet-test     1.0  0.2             1.0     1.0
# 90   miniImageNet  miniImageNet-test     1.0  1.0             0.0     0.0
# 127  miniImageNet  miniImageNet-test     1.0  0.2             1.0     1.0
# 108  miniImageNet  miniImageNet-test     1.0  0.2             1.0     1.0
# 99   miniImageNet  miniImageNet-test     1.0  1.0             1.0     0.0
# 118  miniImageNet  miniImageNet-test     1.0  1.0             0.0     0.0
# 121  miniImageNet  miniImageNet-test     1.0  1.0             1.0     0.0
# 93   miniImageNet  miniImageNet-test     1.0  1.0             0.0     0.0
#
#          distance  test_accuracy  test_top_3_accuracy
# \t
# 102  cosine_scale        0.54172              0.88832
# 124           sen        0.52648              0.87912
# 105     euclidean        0.52612              0.88124
# 96   cosine_scale        0.52608              0.87768
# 111  cosine_scale        0.52496              0.87680
# 90   cosine_scale        0.51988              0.87504
# 127           sen        0.51232              0.87088
# 108     euclidean        0.50896              0.86884
# 99      euclidean        0.50884              0.87048
# 118           sen        0.50752              0.87052
# 121           sen        0.50576              0.87296
# 93      euclidean        0.50084              0.87060

# %% [markdown]
# ## GoogleLandmarks -> GoogleLandmarks

# %%
records_miniImageNet_miniImageNet = records[(records['dataset'] == 'google-landmarks') &  (records['test_dataset'] == 'google-landmarks-test')]
records_miniImageNet_miniImageNet
# Out:
#               dataset           test_dataset  n_shot    k  aux_rotation_k  \
# \t
# 145  google-landmarks  google-landmarks-test     5.0  1.0             1.0
# 136  google-landmarks  google-landmarks-test     5.0  1.0             0.0
# 139  google-landmarks  google-landmarks-test     5.0  1.0             0.0
# 142  google-landmarks  google-landmarks-test     5.0  1.0             1.0
# 148  google-landmarks  google-landmarks-test     5.0  1.0             1.0
# 133  google-landmarks  google-landmarks-test     5.0  1.0             0.0
# 151  google-landmarks  google-landmarks-test     5.0  0.2             0.0
#
#      dfmn_k      distance  test_accuracy  test_top_3_accuracy
# \t
# 145     0.0     euclidean       0.391510             0.550580
# 136     0.0     euclidean       0.389737             0.549083
# 139     0.0           sen       0.384067             0.541423
# 142     0.0  cosine_scale       0.382373             0.539007
# 148     0.0           sen       0.382197             0.538610
# 133     0.0  cosine_scale       0.375750             0.532150
# 151     1.0  cosine_scale       0.375173             0.537263

# %% [markdown]
# ## miniImageNet -> GoogleLandmarks

# %%
records_miniImageNet_miniImageNet = records[(records['dataset'] == 'miniImageNet') &  (records['test_dataset'] == 'google-landmarks-test')]
records_miniImageNet_miniImageNet
# Out:
#           dataset           test_dataset  n_shot    k  aux_rotation_k  dfmn_k  \
# \t
# 110  miniImageNet  google-landmarks-test     1.0  0.2             1.0     1.0
# 123  miniImageNet  google-landmarks-test     1.0  0.2             0.0     1.0
# 101  miniImageNet  google-landmarks-test     1.0  0.2             0.0     1.0
# 104  miniImageNet  google-landmarks-test     1.0  0.2             0.0     1.0
# 107  miniImageNet  google-landmarks-test     1.0  0.2             1.0     1.0
# 126  miniImageNet  google-landmarks-test     1.0  0.2             1.0     1.0
# 120  miniImageNet  google-landmarks-test     1.0  1.0             1.0     0.0
# 98   miniImageNet  google-landmarks-test     1.0  1.0             1.0     0.0
# 117  miniImageNet  google-landmarks-test     1.0  1.0             0.0     0.0
# 92   miniImageNet  google-landmarks-test     1.0  1.0             0.0     0.0
# 95   miniImageNet  google-landmarks-test     1.0  1.0             1.0     0.0
# 89   miniImageNet  google-landmarks-test     1.0  1.0             0.0     0.0
#
#          distance  test_accuracy  test_top_3_accuracy
# \t
# 110  cosine_scale       0.154273             0.247513
# 123           sen       0.154223             0.248230
# 101  cosine_scale       0.153877             0.246670
# 104     euclidean       0.153243             0.246063
# 107     euclidean       0.150200             0.242930
# 126           sen       0.149843             0.242270
# 120           sen       0.124103             0.208803
# 98      euclidean       0.123120             0.207670
# 117           sen       0.119233             0.203487
# 92      euclidean       0.117967             0.200723
# 95   cosine_scale       0.114643             0.197450
# 89   cosine_scale       0.097750             0.175857
